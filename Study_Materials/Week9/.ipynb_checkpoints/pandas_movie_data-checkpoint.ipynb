# %% [markdown]
# # 202001549 장희권

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np

# %%
date_list = pd.date_range("2022-10-01", periods=30, freq="D")

url = "https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=pnt&date="

movie_title = []
movie_point = []
movie_date = []

for today in tqdm(date_list):
    today_url = url + today.strftime("%Y%m%d")
    
    html = urlopen(today_url)
    soup = BeautifulSoup(html, "html.parser")
    
    titles = soup.find_all("div", {"class": "tit5"})
    points = soup.find_all("td", {"class": "point"})
    
    titles_text = []
    points_text = []
    date = []
    
    
    for t, p in zip(titles, points):
        titles_text.append(t.text.strip(" \n"))
        points_text.append(float(p.text))
        date.append(today)
        
    movie_title += titles_text
    movie_point += points_text
    movie_date += date
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
df = pd.DataFrame({"date": movie_date, "title": movie_title, "point": movie_point})

movie_point_sort = pd.pivot_table(df, values=["point"], index=["title"], aggfunc=np.mean).sort_values(by="point", ascending=False)
movie_point_sort.head(1)
# Out:
#          point
# title
# 탑건: 매버릭   9.77

# %%
movie_point_sort
# Out:
#                                     point
# title
# 탑건: 매버릭                          9.770000
# 인생은 뷰티풀: 비타돌체                    9.721667
# 클라우스                             9.687667
# 극장판 짱구는 못말려: 수수께끼! 꽃피는 천하 떡잎 학교  9.625000
# 할머니의 먼 집                         9.620000
# 그린 북                             9.600000
# 밥정                               9.591667
# 가버나움                             9.590000
# 아바타 리마스터링                        9.536667
# 베일리 어게인                          9.532000
# 원더                               9.530000
# 아일라                              9.520000
# 극장판 바이올렛 에버가든                    9.500000
# 디지몬 어드벤처 라스트 에볼루션 : 인연           9.498667
# 당갈                               9.490000
# 포드 V 페라리                         9.480000
# 먼 훗날 우리                          9.477000
# 명탐정 코난: 할로윈의 신부                  9.462667
# 주전장                              9.460000
# 쇼생크 탈출                           9.460000
# 극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교    9.454348
# 터미네이터 2:오리지널                     9.450000
# 장민호 드라마 최종회                      9.444667
# 클래식                              9.440000
# 덕구                               9.440000
# 라이언 일병 구하기                       9.432333
# 나 홀로 집에                          9.430000
# 그대, 고맙소 : 김호중 생애 첫 팬미팅 무비        9.430000
# 월-E                              9.420000
# 사운드 오브 뮤직                        9.420000
# 빽 투 더 퓨쳐                         9.420000
# 보헤미안 랩소디                         9.420000
# 위대한 쇼맨                           9.410000
# 인생은 아름다워                         9.410000
# 포레스트 검프                          9.410000
# 글래디에이터                           9.410000
# 타이타닉                             9.410000
# 살인의 추억                           9.400333
# 헬프                               9.400000
# 매트릭스                             9.400000
# 센과 치히로의 행방불명                     9.400000
# 태극권                              9.391000
# 캐스트 어웨이                          9.391000
# 가나의 혼인잔치: 언약                     9.390667
# 쉰들러 리스트                          9.390000
# 토이 스토리 3                         9.390000
# 씽2게더                             9.389667
# 헌터 킬러                            9.387333
# 히든 피겨스                           9.382000
# 죽은 시인의 사회                        9.380000
# 어벤져스: 엔드게임                       9.380000
# 반지의 제왕: 왕의 귀환                    9.380000

# %% [markdown]
# # 나의 생각
# 1. 2022년 10월 1일 이후 내가 본 영화는 4개이다. 즉 내가 최근에 본 영화들의 평점이 어떠한 지 궁금했고 찾아보았지만 없었다. 없는 이유는 아마 조회순이 아닌 평점 순이라 평점이 높은 영화가 위로 올라가서 안 나오는 거 같다.
# 2. 그 기간 동안 가장 평균 평점이 높은 영화는 탑건: 매버릭이었다. 나도 본 영화지만 진짜 멋있고 가슴이 웅장해지는 톰 크루즈 형님이 주연을 해서 그런지 평점이 높은 거 같다

# %% [markdown]
# # 202001549 장희권
