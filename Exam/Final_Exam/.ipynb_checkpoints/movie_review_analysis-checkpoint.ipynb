# %% [markdown]
# # 202001549 장희권

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from tqdm.notebook import tqdm
import time

# %%
driver = webdriver.Chrome(r"../chromedriver.exe")
main_url = "https://movie.daum.net/main"
driver.get(main_url)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4636\1296405975.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"../chromedriver.exe")

# %%
movie_name = '완벽한 타인'

time.sleep(1)

search_path = '//*[@id="mainContent"]/div/div[1]/form/fieldset/div/input'
driver.find_element("xpath", search_path).send_keys(movie_name)

time.sleep(1)

click_path = '//*[@id="mainContent"]/div/div[1]/div/div/div/ul/li[1]/a'
driver.find_element("xpath", click_path).click()

time.sleep(1)

gradeButton_path = '//*[@id="mainContent"]/div/div[2]/div[1]/ul/li[4]/a'
driver.find_element("xpath", gradeButton_path).click()

# %%
while True:
    time.sleep(1)
    try:
        viewMore_path = '//*[@id="alex-area"]/div/div/div/div[3]/div[1]/button'
        driver.find_element("xpath", viewMore_path).click()
    except:
        break

# %%
grade_list = []

li_class_name = 'cmt_info'
elements = driver.find_elements("class name", li_class_name)

sentence_class_name = "desc_txt"
ratings_class_name = "ratings"
for i, element in enumerate(tqdm(elements)):
    if i%50 == 0:
        time.sleep(1)
    try:
        rating = element.find_element("class name", ratings_class_name).text
        sentence = element.find_element("class name", sentence_class_name).text
        grade_list.append([int(rating), sentence])
    except:
        pass
# Out:
#   0%|          | 0/1995 [00:00<?, ?it/s]

# %%
grade_list
# Out:
# [[8, '이서진 연기 이렇게밖에 못했나싶은.\n재미있는데 이서진은 미스캐스팅인듯.'],
#  [8, '염정아씨 연기.... 최고'],
#  [8, '사람의 속내를 다 알고 나면 그사람과 관계를 유지할수 있을까\n없을거 같다\n그래서 사람들은 안그런척 하고 살아가고 있다'],
#  [10, '사람은 누구나 세개의 삶을 산다. 공적인 삶, 개인적인 삶, 비밀의 삶. '],
#  [8, '최고의 공포영화'],
#  [7, '염정아 다시 봤음. 물흐르듯. 짱.'],
#  [10, '원작을 훨씬 뛰어넘는 수작\n감독의 연출과 배우들의 뛰어난 연기가\n보는내내 즐거움을 느끼게함'],
#  [10, '생각할것이 많아지는 영화!\n인생영화'],
#  [7,
#   '한 장소에서, 하나의 주제를 가지고 배우들이 핑퐁게임을 하듯 주거니 받거니 하는데 서서히 긴장감이 고조된다. 그와중에 부부들의 고민과 21세기 한국 사회의 온상, 그리고 깨알웃음을 주니 만능 엔터테인 영화다.'],
#  [7, '김지수가 맡은역할 정신과 의사.\n가장 열등감에 쩔어있는 모습 인상적이었다.'],
#  [9, '재밌. 유해진 식탁에 양다리 올린게 ♪♪ 웃기네. 드립으로 한건가ㅋㅋ'],
#  [10, '정말 재미있게 본 영화 '],
#  [10, '인간의 본성과 심리에 대해 생각해볼 수 있었던 영화. 베리 굿'],
#  [8, '이거슨 공포영화...'],
#  [9, '복잡 미묘한 사람의 심리 세계를 재미있게 잘 그렸네요\n좀 살아본 사람들은 공감할수 있는 영화^^'],
#  [10, '재미있게 잘 봤다. 스토리 연결도 완벽하고  가볍지도 않고 코믹스러워 한참 웃으며 봤다.'],
#  [10, '굉장히 재미있었다. 배우들의 연기가 다들 훌륭해서 보는 내내 몰입했다.'],
#  [8,
#   '김지수가 그 게임을 하자고 처음 제안했는데.. ㅎㅎ\n본인은 남편의 40년 지기 친구인 이서진과 바람피는 사이 (목걸이ㅋㅋ) \n지도 이서진에게 전화 • 톡 • 문자 할 일없으니\n그 자리에 있는 이서진도 김지수에게 전화 • 톡 • 문자\n할 일 없으니 두사람의 비밀은 보장된 상태이니\n자신있게 그 게임을 하자고 ㅋㅋ\n정신과 의사 예진(김지수)이 가장 나쁜 ㄴ\n이서진은 개이고 ㅋㅋ'],
#  [8, '윤경호는게이였고 이서진은개였다'],
#  [9,
#   '나, 가족, 그리고 지인들을 돌아보게 되는 영화. 잘 안다고 생각했던 사람이 사실은 너무도 다른 모습이며, 나도 나만의 영역이 필요하듯 모두 다 내 영역을 지키며 관계를 맺어가는 것인가'],
#  [5, '..'],
#  [9, '시나리오가 좋네요 전 뒷부분 결말이야기도 좋았습니다'],
#  [10, '우연히 보게된 영화 \n많은 생각과 여운을 남기지만 \n기분좋게 끝난 영화'],
#  [10, '맛깔진 시나리오에 그 맛을 더욱 풍미있게 살려낸 연출과 캐스팅들. '],
#  [9, '적당히 가면 쓰고 사는게 삶의 지혜다. 등장인물들끼리 말만 주고 받는데도 몰입감이 상당했습니다.'],
#  [8,
#   "ㅋㅋㅋㅋ 처음엔 '내가 이래서 모임이 싫지..'하다가 염정아 덕분에 웃었어요ㅋㅋ 웃으면 안되는거지만 영화니까..!! 근데 정말 이래서.. 모임.. 인간 관계.. 싫어요.. 역시 사람이 그냥 그런건 없구나 싶으면서도 자기가 그럴만한 이유가 있으면 남도 그런건데 왜 그렇게 그건 생각을 못 할까 싶어서 참 숨 막히네요ㅜㅠ "],
#  [8, '재밌긴한데, 이서진 커플과 김지수 좀 이해 안간다.'],
#  [5, '원작을 봐서인지 아무 감흥이 없다'],
#  [10, '아래 일본 영화 표절했다는분~~??\n이거 이탈리아 영화가 원작입니다. 한국에서 리메이크한거요.'],
#  [1, '별로였 음'],
#  [9, '영화는 재미 있으나 이서진의 연기는 극의 흐름을 깨는 듯...'],
#  [8,
#   '원작 소설이 있는지는 모르지만 내용이 완벽히 일치하는 프랑스 영화 [위험한 만찬 nothing to hide, 2018]가 있다. 영화 초반 낯설지 않은 흐름에 판권을 구입하여 리메이크한 듯한 느낌을 받음. 각색은 너무 자연스럽게 잘 되어서 프랑스 원작 보다 훨씬 흥미로웠고 익숙한 추억과 기억 그리고 일상을 소재로 다루어서 3배는 재밌었다. 배우들의 연기는 최고였다. 친구들과 같이 보며 나도 같은 게임을 즐겨보고 싶다. 이탈이아판 영화도 있다면 아마 소설이 있고 유럽 각국에서 제작이 되었을 가능성도 있어 보임.'],
#  [10, '진짜 재밌음... 아주 짜릿하고 계속 긴장하면서 봤음\n너무 재밌음 진짜로'],
#  [9, '이게 현실이지 뭐, 가까이있지만 결국은 타인인게 하지만 이서진 너는 도가지나쳐'],
#  [3, '결국 남자들끼리는 알아서 감싸주는 영화ㅋㅋ\n비밀은 없다~'],
#  [4,
#   '좋은 얘기들은 소위, 전.문.가.라는 양반들이 쌍수를 들어 환대하면서 써대서 본인은 걍 넘어가고.\n\n연기는 좀 괜찮은 것 같은데, 대사(각본)를 쓴 작가와 제작진들이 무슨 생각인지 중간중간에 툭툭 내던지는 폭탄들이 상식적으로 이해가 안 가는 수준이라고 생각된다. \n상황을 만들어내는 것은 좋은데, 툭툭 던지는 대사 자체의 수준이 몰입시점에서 그 흐름을 방해하는 지대한 역할을 하면서 몰입감을 방해한다. \n\n근데... 어거 어디선가 본 것 같은 구성과 분위긴데 ... ...???\n리메이크작이라는 얘기는 쏙 빼놓네...\nPerfect Strangers / Perfetti sconosciuti (2016)  /Teleioi xenoi (2016) / Perfectos desconocidos (2017)'],
#  [6, '여기서 제일 나쁜사람이\n친구 마누라하고 바람핀 인간\n용서받지 못할 자'],
#  [8,
#   '연극으로 만들면 더 몰입감이 있을듯...\n누구에게나 비밀은 있다라는 전제하에 서로의 내면을 관객들에게 투영하게 만드는 심리게임같은 영화 \n이거보고 나오면서 커플간에 서로 우리도 해보자고 말안한 커플은\n비밀이 있다는 ㅋㅋ'],
#  [9, '한 장소에서 스토리 진행되는게 연극 시나리오 같아요. 긴장감이 좋았구요. 특히 염정아 조진웅 유해진씨 연기가 좋았습니다.'],
#  [8,
#   '보면서 감정이 이입되어 짜증이 나면서 재미도 느껴지는게\n연기들을 참 잘하시는 것 같아요.\n열린 결말이 아니라 그런지 더 괜찮은 것 같네요.\n굉장히 한정된 공간에서 촬영한 영화라고는 느껴지지 않을 정도입니다.'],
#  [9, '유해진!!!ㅋ'],
#  [8, '시간가는줄 모르고 재밌게 보았다.\n정말로 다아는것이 꼭 행복이지도\n모르는것이 꼭 불행이지도 않는다는 말이 맞는것 같다.'],
#  [10, '와이프랑 보면서 나도 모르게 핸드폰을 뒤집어 났다... 올 문자도 없는데 ㅋ'],
#  [10,
#   '한국사회뿐만아닌,사람이사는곳, \n남자,여자가 있는 한 이루어지는 평범하지 않지만 평범하게 돌아가는 일들..그것이 참,무섭다 \n알아도 눈을가려야,들어도 귀를 닫아야,  행복해질수있는 세상..파헤치면 불행해지는건 내 몫~!!'],
#  [9, '모든걸 안다고 행복해지는 것도\n\n모른다고 불행한 것도  아닙니다'],
#  [10, '아무기대없이 봤다가 한대 쳐맞은 느낌. '],
#  [9, '현실은 언제나 진실의 거짓이다 ㅋㅋㅋㅋ'],
#  [6,
#   '나만 단순하게 사나. 저렇게 사는 사람들은 이영화보면서 원래 다들 저렇게 사는거야~ 라고 자기합리화하겠지? 그냥 영화로는 그럭저럭 볼만함. 막장유머라고해야하나'],
#  [10, '엄청 재미잇음 유해진 대박 욱김ㅋㅋ'],
#  [10, '전니 잼있구만! 잼없다는 인간들 언챙이냐?'],
#  [5, '다들 연극하는 것같은 어색한 연기\n일부러 그랬나싶은... \n연극 보는 느낌'],
#  [0,
#   '이 영화가 옹호한 게이가 지금의 이태원발 코로나를 만들었다\n게이 옹호하지마\n무슨 인간적안 대우를 해줘야하네마네\n게이 욕하면 그러면 안된다고 이야기해주고 웃기다\n위선자들이 만든 게이 이미지가 \n피해자??\n에이즈 감염원이고 국가돈으로 체료받고\n더럽게 흥청망청 몸 굴려서 세상을 더럽개 만들고 있는대'],
#  [1, '빵점 \n드럽게 수준 떨어지네 ㅋ'],
#  [1,
#   '그래서 영화가 말하고싶은게 뭐지? 타인의 비밀은 존중돼야 하니까 배우자가 바람피우고 애까지 가져도 영원히 모르고 살면 괜찮다는건가? 비밀이 까발려졌기 때문에 추해진게 아니라 이미 추한짓을 저질러서 관계를 망친거다. 애초에 추한 비밀을 만들지 말아야지 이걸 숨기면 괜찮은 비밀쯤으로 마무리하는게 더럽게 역겹네.'],
#  [2,
#   '관객은 집단 관음증인가\n뭔지 불쾌한  영화\n인간들의 음지인 부분을 엿보며\n관객들의 킬킬대는 소리\n나만 이상하구나\n내 주변에서 남 뒷담화 제일 잘하는 사람이\n제일 재밌어 하든데 ㅠㅠ'],
#  [8, '원작보다 월등히 재밌다. 훌륭한 연기가 빛났다. 빵빵터졌다. ㅋㅋ'],
#  [3, '그다지;; 설정만있는..'],
#  [1, '완벽한타인은  지옥이다'],
#  [10,
#   '각자의  다른 연기에  정말 심혈을 기울인 연기 감상인게 봤습니다\n특히나 염정아님의 연기 찬사를 보냈니다 앞으로 더욱더 크게 성공할거라고 믿습니다     응원할게요~~^^\n출현한 모든분들 응원합니다 파이팅~~~~~'],
#  [10, '완벽한 스토리.\n연극 무대에서도 보고 싶다.'],
#  [7, '할거면 예진처럼'],
#  [6, '한명의 미스캐스팅이 몰입도를 떨어뜨린다..'],
#  [5, '인지도 있는 배우중에  연기력이 정말 창피한 수준의 배우.'],
#  [9, '유해진 조진웅 멋있었음.'],
#  [9, '괜찮은 영화~ 딸가진 아빠로 중간에 나오는 조언 좋았습니다.'],
#  [9, '재밌네.몰입감 굿'],
#  [7, '연기 모두 좋고 누구에거나 비밀은 있다'],
#  [9, '바람피우고 있는 사람들에게는 공포 영화'],
#  [10, '제작비도  많이  안들이고   저정도면  잘된 영화   스토리 연기 좋았는데  이서진이  좀  어색했음'],
#  [7, '걸려버렸네'],
#  [8, '재밌어요 모르는게 약이다'],
#  [10, '영화로 만나는 내면의 날것. 그걸 남에게 드러내는 공포.'],
#  [8, '잔혹..'],
#  [10,
#   '배우들의 연기력도 좋고 내용 전개도 좋아서 몰입하면서 봤네요~\n그리고 엄청 재미있기도 하고 생각이 많아지는 그런 영화인거 같아요 👍'],
#  [9, '오랜만에 웃었네요.. 완전'],
#  [6,
#   '철지난 영화지만\n넷플서 봤는데\n볼만함\n넷플서 위험한 만찬을 먼저봐선지\n그것보단 못했지만\n한국실정에 잘맞게 해석한듯\n근데 제작비 50억 넘는건 이해불가\n스타급 배우들이라 출연료가 비싼건가?'],
#  [10, '재밌게 잘 봤습니다'],
#  [10, '재미있다 무엇보다 한국영화들 우물거려 무슨말인지 통 알수없는게 없어서 좋고 신선해서 좋고\n연기력들 최고이다'],
#  [7,
#   '이정도 연출과 각본이면 훌륭하죠. 연기야 다들 수준급 배우들이라 말할 것도 없구요. 단지 영화인데 연극같은 느낌? 전체적으로 과장을 줄였으면 어땠을까 아쉬움이 있네요.'],
#  [7, '원작만큼은 아니지만 쏘쏘'],
#  [10, '재밌게본영화입니다~'],
#  [8, '사람이란\n결국 씁쓸한  존재'],
#  [10, '...'],
#  [8, '재밌게 봤는데\n리메이크였나요?\n리메이크 아니었으면 9점 이상 줬을건데'],
#  [7, '킬링타임용으로 괜찮았다. 지루하지 않게 해줘서 좋았고, 결말의 구성과 연출이 마음에 들었다.'],
#  [10, '굿!!!!'],
#  [8, 'ㅋㅋ'],
#  [7, '사랑과전쟁 ㅋ'],
#  [8, '사랑하면 지켜주고 싶은거야 새끼들아'],
#  [10,
#   '사생활을 공유하는 게임이  비현실적이지만   서로  다투는  눈빛과 말투에서  잘못된게임이  진행되고  개인핸드폰 속에서   비밀들이  드러난다.   착한척 .고상한척 . 연기의 연속이라는  생각이 들어  씁쓸했다.   '],
#  [9, '꿀잼! ㅋㅋ'],
#  [7, '.'],
#  [8, '재미있게 잘 봤네요 ^^'],
#  [10, 'ㅋㅋㅋㅋ유해진 ㅋㅋㅋㅋㅋㅋ\n게이로 오해받을ㄸㅐ  표정연기 쩔엇~*'],
#  [9, '재밌게 잘 봤습니다.'],
#  [6, '속이고속이는 인생만 있는것은 아님'],
#  [7,
#   '게임하는 쪽이 와장창 깨져서 매우 아프고 후폭풍이 크겠지만 속 시원하고 몇몇 인물은 더 잘 살아가지 않을까 싶다 염정아의 경우 죄책감은 가시방석인데 안고 가지 말고 터뜨려진것이 훨씬 낫다고 본다 이서진 부인의 경우도'],
#  [10, '근데 사람들은 정말 저런 편견과 선입견을 가지고 있나요?'],
#  [6, '다름을 틀림으로 보는 한국인 식탁, 그래서 씹을건 많다.'],
#  [10,
#   '캬.. 정말 신선한 소재.. 예상을 뛰어넘는 스토리.. 웃음 포인트를 정확히 아는 연출력... 맛깔스럽게 연기하는 배우들... 기가 막히다...이 맛에 돈들여 시간들여 영화 보는 거지 암...'],
#  [9, '그래. 가까운듯 완벽한 타인이 배우자야'],
#  [10, '엑시트 다음으로 또 한 번 나를 웃게 해 준 영화'],
#  [10, '액션없이 대화만으로 쉴틈없이 쫄깃쫄깃했던 영화'],
#  [9, '재밌어요.결말은 조금..'],
#  [8, '얼마나 웃엇는지 \nㅋ\n단순 주제가 이렇게 많은 이야기를\n끌어낼수잇다는게\n새롭네여'],
#  [10, '재밌다'],
#  [9, '이미 흥행성공한 리메이크 작품입니다 \n\n한국 유명한 영화들 리메이크 작품 많습니다'],
#  [10, '두번봤는데 다시봐도 잼있네요\n꼭 보시길'],
#  [10, '재미있고 의미도있네요'],
#  [9, '신선하고 창의적인 소재\n철학적 주제'],
#  [10, '굿'],
#  [10, '시간가는 줄 모르고 봤네요. 각본의 짜임새가 굿~'],
#  [9, '너무 재밌어요'],
#  [8, '생각이 많아지는 영화'],
#  [8, '내 자신의  심신안정을 위해서는  모르는게  약!!'],
#  [10,
#   '민수씬에서 야밤에 박장대소했습니다.\n평범한듯~깊이있고!\n힘있는 얘기가 있어 왜진작 못봤나\n후회됩니다^^\n멋진영화 배우님들과 감독님들\n연휴 후 출근하기싫었는데~~\n힘을 주시네요^^'],
#  [9, '내용이 정말 많은 걸 담고 있네요.\n잘봤습니다~~'],
#  [10, '생각이 많아지는 영화! 관계 말 등등'],
#  [10, '엄지척'],
#  [8, '생각보다 훨 재밌네요'],
#  [10, '대한민국 영화의 명품이다. \n다시 봐도 참 잘 만들었다. 연기도 좋고...'],
#  [8, '신선했어요 '],
#  [10, '간만에 훌륭한 영화를 봤네요'],
#  [10, '재미있네요 \n유해진씨  연기에 많이 웃었어요ㅋㅋ ㅋ'],
#  [9, '시나리오 괜찮고 마지막 반전도 좋았음~ 별것도 아닌건 서로 모르고 사는게 약일때도 있는법이지..'],
#  [10, '굿'],
#  [9, '많은것을 생각하게 만드는 영화네요'],
#  [10, '결론은  게임을  안 했군...  다들 비밀은  있을 듯 ..   \n커플인 경우 모르는게 약인가? ㅋㅋ'],
#  [9, '이렇게 재밌는영환줄 몰랐네요진짜 ㅋㅋ'],
#  [6, '응?? 게임이 게이를 이해하기 위한 루틴인가? '],
#  [10, '너무 디테일하고 재밌어요 유해진씨 연기 너무 잘하세요'],
#  [10, 'ㅋㅋㅋㅋㅋㅋㅋ이 재밋는걸 이제 보다니 ㅋㅋㅋ'],
#  [9, '유해진이 게이연기 재미있네요...\nㅋㅋㅋㅋ'],
#  [9, '재밌다 재밌어'],
#  [5, '진상들!'],
#  [10, '재미있게 봤습니다ㅎㅎㅎ'],
#  [9, '새로운영화\n재밌네요'],
#  [1, '유치빵~2인자들ㅋ수준하고는~에휴서진.해진.욕나온다이~'],
#  [0, '평점  조절'],
#  [10, '너무 좋고 정말 재미있어요  또 보고 싶다는 생각이 들어요'],
#  [7, '기대이상으로 아주 재밌게봤다'],
#  [7,
#   '공부 더 많이 하면 심성과 인성이 저절로 높아지지 않는다. 서울대 출신들이라 학교를 빛낸 거라면 그 외 학생들은 뭐지? 전형적인 일그러진 인간상과 속과 겉이 다를 수도 있는 인간성을 보여주려는 영화. 니들이랑 사는 게 닮아서 이 영화 재밌냐? 제 멋대로 사는 주제에 뭐 좀 갖췄다고 시건방 떨면서 신을 욕하기는ᆢ 조물주의 말씀처럼 인간은 죄인이다. 서로 모르는 게 약인 인생ᆢ'],
#  [10, '너므 너므 잼났음'],
#  [8, '우리들이 살아가는 모습을 제대로 보여주는거 같아서 좋음.\n 석호 딸이 돌아온건 잘한 선택이라고 생각함.'],
#  [9, '개웃기고 재밋어요 ㅎㅎㅎㅎ'],
#  [9, '신선하고 재미있네요. 소문 듣고 이제서야 봤는데도 잼나요\n연기들이 좋네요..명배우들이라 역시..'],
#  [9, '깔끔하고 새롭다'],
#  [5, '소문난 잔치에 먹을 것 없는, 억지로 대사를 먹고 있는 그와 그녀들'],
#  [8, '한국영화에서 보기드믄 신선함!'],
#  [5, '소재는 기발하지만 큰재미는 없다.\n연기의 케미가 떨어진다.'],
#  [7, '.'],
#  [10,
#   '비밀의 나, 별다른 게 없어서.....   9점을 줄랬더니,   곰곰히 생각할수록 하나둘 떠오르기 시작하네. 그래서 어쩔 수 없이....'],
#  [8, '잼났어요'],
#  [8, '모르는게 약이다.  라는 말이있죠'],
#  [9, '굿'],
#  [8, '그냥 내가 생각하고 싶은 대로 주변 사람들을 생각하며 사는게 가장 평화롭다 주변 사람들을 시험하지 마 나만 다쳐'],
#  [9, '완벽이 없다 하니 다른 점수를 줄 수 없고 9점을 줄 수 밖에..'],
#  [10,
#   '뒤돌아보면 평생토록 잊지 못할 순간이 있다. 인생에 있어서 빛나는 순간이 있어, 나중에 돌이켜 봤을때 그게 오늘이라고 생각된다면 그냥 가. 그게 아니다 싶으면 돌아와 그런데 아빠가 아닌 너보다 인생을 좀 더 오래 산 사람으로서 말하자면 너에게는 아직 많은 시간이 있다는 거야/ 명대사 '],
#  [7, '킬링타임용으로 딱'],
#  [8, 'ㅋㅋㅋ 잼나네..'],
#  [9, '사람 마음은 알 수 가 없군요ᆢ'],
#  [1, '한국영화를 뒷걸음 치게하는 영화'],
#  [7, '집안에 펼치는 각자의 치부가 적나라하게 들어 나는 영화, 웃음과 씁쓸함 둘다를 경험할 수 있는 영화.'],
#  [5, '뭐지...?'],
#  [9, '아무생각 없이 봤다가 완전 푹빠져 본 영화. 역시 유해진이더만...'],
#  [8, '완성도 높은 코미디 영화'],
#  [2, '기대이하.\n신선함도 없고\n지루함'],
#  [10,
#   '평점 이상하네?? 난 진짜 잼있게 봤는데....\n끝나지 않길 바란 영화는 오랜만임....\n연기력도 연출도 다 평타 이상이긴 하지만 \n이 영화는 진심 각본의 승리다!'],
#  [3,
#   '왠만한 영화는 끝까지 보는 편인데... 1시간 정도 보다가 껐네요...\n\n인간군상에 대한 꼴불견을 지나치게 묘사해서 보는 내내 불편하네요...'],
#  [6, '이서진 연기 꽝 '],
#  [3, '이서진커플 꼴불견. 이서진 연기력 ㅠㅠ'],
#  [10, '감독에게 박수를.   '],
#  [5, '인간 또는 부부 관계에 대한 이해. 하지만 지루하다.'],
#  [1, '원작은 대박이었는데 이건 그냥.. 미국판 올드보이 보는줄 '],
#  [10, '재밌다. 나 자신이나 사람들을 다시 생각하게 만드는 영화네요 '],
#  [10,
#   '이 영화의 평점이 들쭉날쭉한건 사람들을 불편하게 만드는 영화이기 때문이라고 생각한다.\n또는 바른 삶만을 살아와서 공감이 되지 않거나. 혹은 동성애가 불편하거나. \n나는 참 아이디어하고 각본이 좋다고 생각했는데 원작이 있고 원작과 거의 흡사하다는 소리를듣고\n아 뭔가 난잡스러운게 한국보단 좀 더 프랑스스타일이긴 하구나 생각이 들더이다.'],
#  [6,
#   '남들이 너무 재밌다고 한 것에 기대를 많이 했나 보다. 솔직히, 실제 시도되지 않았지만 콩가루 같은 친구관계와 불륜의 이야기를 그리 재밌다고 말하기에는 개인적으로는 별로였다. 한편으로 배우와 극중 배경인 집 렌탈로 영화를 찍었다면 제작비는 얼마 안들고 그렇다고 창작 시나리오도 아니라 외국 영화를 각색한 거라 등골 뺄 일은 없어서 좋았겠다 싶었음. 그 이야기가 모두 공감되는 것은 전혀 아님을 알아야 할 것.'],
#  [10, '한정된 공간에서 이야기를 긴장감 넘치게 잘 끌고가네요. 간만에 몰입해서 재미있게 봤어요.'],
#  [10, '재밋게봣눈데 난..'],
#  [4,
#   '"하이 빅스비~" 를 볼 때 쯤 "아오~" 이러면서 꺼버리려다\n"지*랄" 투덜거리며 다 봤음. \n인간이 세상 살아가는데\n겉 다르고, 속 다른 거야 피차일반이라지만\n내 주변에 이런 꿍꿍이 친구들이 없어서 그런가.\n딱히 공감 못하겠음.\n\n다 보고 나서는\n제작사랑 배우들이 \n참 짭짤하게 벌었겠네.\n이 생각이 듦.\n\n알아보니 리메이크 작이고, \n관객 동원수 520만명 돌파라네?\n완전 복 터진게지.'],
#  [8, '엔딩크레딧:\n개 발기시키는 친구 목소리 조정석\n게이 남친 목소리 김민교\nㅎㅎ'],
#  [10, '많은 생각을 하게됨'],
#  [8, '타인은 타인이네요..'],
#  [5,
#   '염정아...\n난 담배 정말 싫어하는 사람인데...\n어찌 그 나이에 담배피는 모습이 그리 섹시하고 멋있어 보이는건지...\n\n그 장면만 기억에 남음..\n\n영화는 그럭저럭...'],
#  [10,
#   '오랫만에 제대로 만든 한국영화 한편을 두시간 동안 화장실도 안가고 푹 빠져서 보았습니다 . \n관객수가 500만명 밖에 안되는것이 이해가 안되네요 . 꼭 보세요 ....'],
#  [8,
#   '영리하고 우아한 막장 코미디\n웃음 뒷끝 서글픔은 나의 몫인 것을\n\n주인공들의 아픔 속에 내가 투영된다.\n준모는 행복할까?\n태수처럼 감당 못할 배려를 하며 살아온건 아닌지,\n석호의 무모한 투자는 인정받기 위한 출구를 찾는 건가?\n현실과 이상을 구분하려는 예진의 비뚤어진 합리주의는 나의 거울이 아니던가 !\n수현처럼 상대의 그늘에 드리운채 사는 이 시대의 여성들, 남성들은 또 얼마나 많을까?\n세경은 그동안 몰랐을까?\n영배가 안스럽지 않은 세상은 언제나 올 수 있을까?\n나는 어떤 방식으로 행복할 수 있을까?\n\n중반부터 가족 모습이 하나둘씩 떠올라 미안함이 엄습한다.\n마지막 반전은 무겁게 생각하지 말아달라는 배려임에도 불구하고 결국 변한 건 없으니 마음이 가벼워지지 않는다.\n\n한잔 술에,'],
#  [10, '엄청 웃었다. 배아프게. ㅋㅋㅋ'],
#  [10, '근 몇년동안 이렇게 웃긴영화 못 본거 같애요 '],
#  [10, '비밀은 비밀'],
#  [7, 'ㆍ'],
#  [10, '김지수 귀고리'],
#  [9,
#   '너무직접적으로 민낮을 까발겨서... 오글오글 때로는 코믹하게....성소수자 의 이야기..까지..\n40년지기 친구 살을맞대고 십수년을 살아도........\n이영화를 보면서 왜 대학살의신 이 떠올랐을까..'],
#  [0, '빵점  진짜 형편없는 영화. 빵점'],
#  [8, '신선하네.'],
#  [7, 'ㅇ'],
#  [8, '타인의 비밀이 드러나는데도 스릴있고 긴박하다.\n세상은 내 자신외에는 모두 타인이다...완벽한 타인'],
#  [8, '수작이다 수작. 연출력과 연기력에 박수를'],
#  [8, '나도 핸드폰 잠금해제 풀고 이 게임을 한다면... 생각하기도 싫다ㅋㅋ'],
#  [8, "재밌게 봤네요.\n'누구나 비밀은 있다' ,  제목때문인지 이 영화가 떠오르네요."],
#  [8,
#   '엄청 재밌다. 핸드폰이라는 매체는 그 사람의 모든 것을 담고 있다. 그것을 까발려주는 영화. 아쉬운 것은 원작 영화와 스토리와 연출이 거의 같다는 것.'],
#  [8, '왜 장르가 코미디인지 모르겠다.\n비밀이 없는 사람도 이해하고 생각해 볼 만한 깊은 영화..'],
#  [7,
#   "원작도 봤었는데 한국영화가 더 재미난듯.  왠지 영화 '대학살의 신'이 한번 더 보고싶다는 생각이 드네요.  그리고 초반쯤 영화속 명대사. 남자는 가격이싸고, 다루기쉽고, 바이러스 잘걸리고, 업데이트 일일히 안해주면 바보되서 안드로이드고, 여자는 이쁘고, 지조있고, 똑똑하고 비싸고 까다롭고 호환이 자유롭지 않아서 IOS라네요. 이 대사에 반박할 사람 몇사람 없을듯."],
#  [8, '타인의 스마트폰을 통해 저마다 숨기고 있는 비밀들을 알게 된다면......'],
#  [8, '완벽한 드라마 '],
#  [4,
#   '동성애코드가 나오지 않는 영화는 없는지..ㅉㅉ\n영화가 말하고자 하는 바는 의미있게 생각해볼만한데 동성애 코드 징글징그루하네여.'],
#  [10, '모든걸 공유할 필요는 없는듯\n흥미진진'],
#  [10, '식탁에서 벌어지는 이야기 지루할 틈이 없네요. 강추 '],
#  [8,
#   '현대인의 병폐 휴대폰속에 갖혀사는 군상을잘표현한 수작이라 감탄했는데 리메이크라 실망이네조금은. 그렇지만 한정된공간에서 오로지 배우들연기가중요한데 이서진이 예능만해와서근가 혼자따로논다 연기를꾸준히한배우와 격차가큰듯.유해진과 염정아연기가 돋보인다 역시 다르다 결국 아무일없이 다시돌아간다...그게 의외인듯 고로 다똑같은인간들이기에..'],
#  [9, '재밌게 잘 봤어요ㅎㅎ'],
#  [9, '배꼽을 잡았네요.\n휴대폰이라는 기계 하나로 이런 스토리를 만들수 있다니. . .'],
#  [8, '배우들의 연기가 너무 자연스럽고 재밌는 영화\n웃음뒤에 관계와 스스로를 다시한번\n돌아보는 영화'],
#  [6, '완벽한것은없다'],
#  [2, '나만 재미없었나요!!\n원작을 안 봤어도 충분히 예상되는 전개'],
#  [9, '9점'],
#  [2, '나만 재미없었나\n그냥 연극  정도로 만들만한 대본\n다들 왜 칭찬하는겨\n너무 더럽다\n설마 다 저렇게 산다고 생각하는거?'],
#  [10, '많은생각하게만든 일상사람들의 이야기..누구에게나 비밀은 있다. 굳히 그걸 알  필요없다.'],
#  [6, '이서진 혼자 붕 떠있다. 적역인 척 착각 오지다. 유해진 완승'],
#  [7, '스마트폰이라는 게 요물이다. 비밀 없이 깨끗한 사람도 있겠지만, 그 비밀 덕분에 공적인 삶을 지속할 수도 있을 터. '],
#  [10, '곽미향ㄷㄷㄷ'],
#  [8, '이런저런 생각이 들게 함'],
#  [7, '공적인 나, 개인적인 나, 비밀의 나.. 그래서 인간은 외롭다.'],
#  [3, '시간이 너무 안감'],
#  [2, '소문을 듣고 기대하고 본 것이 잘못되었다. 한국영화의 전형적인 틀을 벗어나지 못한 그저 그런 영화.'],
#  [9, '8.5점 \n원작이 없었으면 10점'],
#  [10,
#   "2014년 염정아 주연 영화 '카트'를 기억합니다\n연기력도 훌륭했지만 암울한 박근혜시대에 사회 약자, 소외된 노동자의 아픈 삶을 생생히 묘사한 걸작이었지요.\n비록 큰 흥행은 못했으나 카트 후 염정아의 성공발전을 기대하고 확신했었지요.\n\n앞으로도 좋은 연기를 응원할께요"],
#  [8,
#   '염정아 유해진이  이끌어간 영화.\n\n특히나 염정아는  맡은 배역마다  자신이 아닌 듯  배역과 하나가 되는  유일한 배우.\n\n여태보면 어떤작품에서도  똑같은 느낌을 받은 적이 없다. 항상 새롭고  색다르고 완벽하다.'],
#  [8, '공적삶이든 비밀인 삶이든\n개이는 쫌더럽 퉤퉤\n암튼 세계에서 한국이 영화 젤 잘만드는듯\n(2019.1.20 집)'],
#  [7,
#   '잘만든 영화~ 인간 관계에 대하여 생각 해 볼 수 있는 영화\n하도 이서진 연기 지적이 많아서 걱정했는데 튀지는 않던데?\n마지막 동성애만 아니였음 더 좋았을 영화'],
#  [6, '엤날부터 느끼는거지만 이서진이 왜 배우인지 난 도데체 1도 모르겠다.'],
#  [8,
#   '스토리 같은 외국영화를 똑같이 한국식으로 만든거 같은데 외화보다 이 영화까 더 재미있네요 2가지 모두 보았는데 한국식으로 만든 이 영화가 아주 좋았어요 '],
#  [7, '비밀의 나,,,,, 만들어야하나? 두 가지 삶만 있는 사람의 고민.(나만 그런가?)'],
#  [9,
#   '바람 필 놈은 바람 피고, 화해 할 놈은 화해하고, 사랑한다 믿는 놈은 끝까지 그 믿음으로 살고, 주어진 대로 사는 놈은 원래 그런대로 산다... 그래서 타인인거지.... 완벽하게'],
#  [5,
#   '남의방에서 화장하는거부터 응? 했는데 저상황에 반지를 왜돌려.. 인셉션이야 뭐야 했는데 ㅋㅋㅋㅋㅋㅋㅋㅋ 인셉션이었네 ㅋㅋㅋㅋㅋㅋㅋ 그냥 막장그대로 결말나는게 좋았을거 같은데.. 다른건 다 그냥 그럴수 있다 치겠는데 40년지기 친구 마누라랑 바람피는건 너무 쓰레기 아닌가....'],
#  [6, '.'],
#  [8, '관계에 대해서 많은 생각을 하게 되었다.'],
#  [6, '다들 이렇게 살겠지...'],
#  [9, '흥미진진... 잔잔하고도 재미있는 영화다.'],
#  [7, '아슬아슬한 재미가 쏠쏠한 영화'],
#  [6, '생각보다 소소하게 재미있었다. '],
#  [1, '이게 무슨 5백만이나 든 영화인지 모르겠네\n그냥 드라마 하나 보는정도?'],
#  [10, '수작.'],
#  [5, '리메이크였어?\n그럼 별'],
#  [9, '재밌네. 잘 만들었다.'],
#  [7, '의외로 잘 어울리는 영화 '],
#  [8, '난 재밌었는데 ㅋㅋ 이 와중에 조진웅 멋지고 난리'],
#  [8, '영배역의 윤경호씨 이름 알고파서 일부러 검색해 들어왔네요. 진짜 유해진 염정아씨 연기 감탄에소름이고요, 윤경호씨 대박입니다.'],
#  [7,
#   '독특한 설정 속에 오가는 대화가 만들어내는 공감과 긴장감이 만들어낸 수작. 개인적으로 각본이 8할이라 생각되는 작품이다. 물론 그 각본속 역할을 살려낸 배우들과 연출도 있지만 말이다. 이탈리아 원작을 보지 않고 봤다면 더 후한 점수를 매겼을지 모르나, 실상 크게 다른게 없는 거의 같은 작품이기에 원작만큼의 재미는 없었다. 각색도 거의 없고 연출은 더더욱 비슷하고, 유해진의 연기와 추가된 결말 정도가 그나마 눈에 띄었다. 그렇다고 못하다거나 나쁘다는게 아닌 조금 더 각색했어도-하는 아쉬움 정도랄까(원작을 이미 봤기 때문일지도). 원작이든 리메이크이던 좋은 작품은 몇번봐도 재밌다.'],
#  [8, '통수의 통수의 통수의 통수... 배우분들이 연기를 매우 잘하셔서 몰입하기 좋았다'],
#  [5, '이서진연기 따로노는듯 ...'],
#  [10, '재미있다 .  몰입도 최고 \n배우들 모두 연기도 잘하고 '],
#  [8,
#   '저예산으로 최대한 가성비를 뽑아낸 영화...\n몰입감도 좋고, 결말이 궁금해서 보는 내내 집중하며 재밌게 봤다...\n\n이래서,남녀간 부부간 휴대폰 공개를 꺼리고, 하얀 거짓말을 하는거 아니겠냐..\n유부남,유부녀들이 이처럼 많이 바람 피는줄 누가 알았겠냐...\n불륜자들이 싫어할 소재의 영화...'],
#  [6, '유해진이 살린거지 뭐..그 외엔 왜 재밌다고 난리인지 모르겠네\n나도 결혼 16년차인데 공감가는 부분도 있긴 했음'],
#  [7,
#   '신선한 소재\n연기력이 좋아서 그런지  몰입도 최고\n알면서도 모르는척 눈감아 주는것도\n건강한 인생을  살아가는 하나의 방법이겠다'],
#  [9,
#   '돈 억수로 투자해 만드는 졸작들보다 백배훌륭한영화.\n배우들 케스팅,연기,케미 너무좋고\n시나리오 신선하고 훌륭하고\n결혼한 부부들이면 누구나 공감할만한 얘기로\n우리 인간관계에 대한 깊은곳을 한번더 들여다보고\n반성하게 만드는영화 \n이서진 캐릭터 밤맛이지만 연기잘했고\n염정화 유혜진 역시 짱이네요^^\n유혜진- 민수 통화로 게이될때 진짜 빵터짐 ㅎ'],
#  [8, '누구나 있는 불편한 진실..\n나와 지금 마주하고 있는 그 사람도 뒤돌아서면\n내 욕하는 사람일 수 있다.'],
#  [5,
#   '저 세대는 욕 많이 안하는데 아역씬부터 너무 욕이 많았다\n그리고 남자배우중 한분의 외모가 너무 아쉬움\n이서진 부부의 연기는 뭔가 비현실적\n그리고 마지막 불륜암시부분 뜬금없음\n연출이 많이 아쉬웠다'],
#  [10, '솔솔한 재미가득!'],
#  [10, '개잼'],
#  [7, '인간관계의 거리.. 가까운 듯 멀기도...'],
#  [3,
#   '시대적,현실적으로 있을수 있는일이고 tv영화소개로 하도 대대적홍보?하는듯해서 일단호기심이 들었다.\n\n 영화가 한국적 으로 리메이크되었다고 들었는데 원작을 보진못햇지만 먼가 2%부족한 엉성함을 주었고,\n끝에 결말부분서 게임을하지 않았을 경우 귀가상황을 제시하는것은 영화를본 시간을 허탈하게하였다.\n\n게임을 했을경우와 안했을경우를 제시함으로 선택은 각자 자유의 몫이라고 느끼게 하려는 \n감독의 친절함이 불편하게 느껴졌다.\n\n마치 전장나간  아들이 전사통지서를받고 노모와 아내,남은 가족들이 슬퍼하고 고통받으며 역경을 헤쳐가는 영화를 보다가 자막이 바껴 죽지 않고 살아왔을경우를 영화에서 제시해준다면 어떤기분일지 감독이생각해보길바란다.\n총평은 ㅡ영화관서 돈주고 보긴 아까운영화 ,1점\n공짜로 킬링타임용으'],
#  [3,
#   '예전에극장가에명랑흥행1위라고 소개되고 호기심에 극장가서 보고나오면서 그 허탈감  기억난다ㆍ\n\n그때  명랑 ㆍ영화재밋게보셨단분도 계셨다ㆍ\n실제로 명랑흥행성공 햇다지만 ㅡㅡ\n이영화도 그때 생각난다ㆍ\n\n흥행과 작품성의 연관관계에 대한 의구심은\n상업영화화에대한 감독의이해력,\n조직력, 출연배우의  유명세 등,,,..\n그것또한 능력의 일부라면 할말없다ㆍ\n\n다만 나는 영화관가서 보지 않은것에 위안삼으려고 한다ㆍ\n\n킬링타임용으로는볼만하지만ㆍ\n배역들의 부자연스러운 연기력,\n반전같지않은반전등\n또한번 한국영회의 실망감을 안겨준다\n기대가 컷던지 실망도 크다'],
#  [7,
#   '누군가에게는 불편할 수도 또 다른 누군가에는 암유발일 수도 \n그리고 또 누군가에게는 호기심을 유발 할 수도 있을 영화. \n부부 또는 연인의 관계가 아름답게 유지되기 위해서는 상대를 알아가는것도 중요하지만\n꼭 다 알아야 할 필요는 없는거겠죠.\n이서진의 연기가 혼자 따로노는듯 한 단점만 빼고는 좋은 연출력이었다고 생각됩니다.'],
#  [8, '진지하게 웃을 수 있는 영화'],
#  [8, '인간관계의 허무한 면을 잘 표현한 영화네요. 하지만 이서진의 연기는 좀... '],
#  [10, '구성ᆞ전개  좋았어요~   두 번  봤는데\n두번째가  더  와 닿네요~'],
#  [7,
#   '집들이 공간이라는 하나의 장소에서의 에피소드가 이렇게 지루하지 않게 전개될 수 있는 것은 원작의 힘인가? 마지막 자막에서 목소리의 주인공들이 더 대박 ㅎㅎㅎ'],
#  [8, '이탈리아 원작은 물론 프랑스 리메이크작보다 못하다'],
#  [8, '남편과 시간가는줄 모르고 봄. 어벤져스류에만 열광하던 사람도 배꼽잡고 웃더만요'],
#  [10, '현실을 직시할 수 있는 사람만 공감할 수 있는 영화'],
#  [0, '이 영화에 왜 평점을 주어야 하나...'],
#  [8, '개인적이며 각 개인의 분신과 같은 휴대폰이 나의 비밀을 낱낱이 공개해버릴때의 상황을 때로는 긴박하게 또는 유쾌하게 풀어냈다'],
#  [3,
#   '이서진 연기 때문에 화가 날 정도 ㅠ\n아내역 송하윤? 도 너무 안어울리고~\n보면서 내내 이게 500만이라고???왜???  라는 생각뿐..'],
#  [7, '유해진때문에 겁나게 웃었네  ,,, '],
#  [7, '세 개의 삶 '],
#  [9,
#   '오랜만에 연기 잘하는 사람들의 실제같은 진실한 대화를 잘 봤습니다. \n염정아의 혼이 담긴 연기는 진짜 내가 설득당할듯했고, 유해진의 게이연기는 진짜 박장대소했다. 오랜만에 폐쇄된공간에서 벌어지는 스릴러를 잘봤다. 짜임새도 꽤 견고했다. '],
#  [7, '연극보는 느낌이었네요.'],
#  [10, '재밌네요.\n다들 개성있게 연기 잘하시네요.\n지수는 여전히 이뿌네..\n올해는 영화 많이 쫌 해주라..\n건강하고..'],
#  [3, '이서진 연기력에 전부 까먹음'],
#  [7, '시나리오는 최고였는데, 염정아를 제외하곤 배우들 연기가 영 아니더군요.\n특히 이서진의 연기는 그중 최악이었음.'],
#  [3,
#   ' 나 이서진 디게 좋아했는데.....첫 시작부터 오글 터져 죽을뻔...;;; 욕하는거 섹드립 치는거 전부 어색 오글..으억...오늘부터 이서진 싫어짐....설정은 재미난 설정인데...음 배우가 좀 캐릭터랑 안어울리는 느낌이 든다./.'],
#  [10,
#   '영화 잘 만들었다 단순히 재미와 즐거움을 위해 영화를 보는 사람들은 이해 못할테니 아예 보지를 마라 평점 낮게 매긴 애들보니 죄다 그렇고만 '],
#  [10, '하고싶어요안될까요제발보내드립니다!'],
#  [10, '몹시 재미난 설정 디테일 하게 묘사했다!\n새롭고 대담하게 연출 했고 인간에 다중성을 잘 표현한 작품이다 ! 굳 ! 꿀잼'],
#  [7,
#   '나도 이서진 차 안 장면 너무 오글거리던데,  평점 읽어보니 사람생각은 다 비슷하구나. 배우들은 예능에 그래서 너무 많이 출연하면 안 되나 보다. 삼시세끼 자꾸 생각나서 이서진은 무슨 대사를 해도 영화속 캐릭으로는 몰입이 안 됨. 결말 이해 못 하는 사람도 많던데, 끝에 김지수 대사만 제대로 들어도, 다 이해 가는구만. 재미는 있다.   '],
#  [5, '중간 정도 봤는데 끝까지 봐야하나 갈등생기네'],
#  [2, '이서진은 뭘해도 어색해 ᆢ'],
#  [6,
#   '이탈리아 원작은 모르겠고 프랑스판 리메이크 ⟨위험한 게임⟩ 보단 좀더\n재밌게 봤다. 확실히 잘 짜여진 각본과 위험한 비밀이 하나 둘 벗겨질 때 \n느껴지는 묘한 긴장감을  내공있는 배우들의 연기로 잘 그려냈다. \n단, 서울대와 변호사,의사,사업가 등 우리사회 주류층의 허위의식을 \n꼬집는 면이 약간 부족한 듯 싱겁게 웃으며 마무리되는 점은 좀 아쉽다'],
#  [4, '말도 안돼는 이야기를 억지로 짜맞춘영화!!  맨마지막엔 반전이더만 ㅋㅋ..  허접하다 허접'],
#  [8, '완전 막장 인싸들의 게임  '],
#  [0,
#   '영화속 인물들의 가공된 허구의 사생활이 그리도 궁금하더냐 ? 하튼 궁금증과 오지랖넓은 한국사람들의 입맛을 노리긴했네 ㅎㅎ  영점도 아깝다. 마이너스 없는걸 다행으로 알아라..'],
#  [8, '남자들 외모가 좀. .아쉽네요 쩝,,,,'],
#  [1, '노잼'],
#  [7, '진짜? 가짜...잠깐 뜨끔 하게 했던 영화....결말이 아쉬워..그래서 7점'],
#  [9, '늙어 보이는 염정아 배우님\n슬퍼요'],
#  [7, '갈수록 뭐 이리 막장으로 가나 싶었는데 음..\n나름 반전도 있고 공감도 가고 나쁘지 않았어요'],
#  [8, '주제에 충실한 대본을 좋은 배우들이 열연해 잘 구현해주었네요. \n특히 유해진 배우, 아주 칭찬해요.'],
#  [8, '참신하고 색다르고 재미있고..'],
#  [8, '유해진 진짜 연기잘한다.'],
#  [8, '결말이 인셉션... ㅋㅋㅋ 이것도 스폰가?'],
#  [10, '묘하다 재밌다가 쫄깃하고 화났다가 슬프고'],
#  [7, '내 옆에 있는 사람들은 무슨 생각을 하고 사나'],
#  [7, '이 영화 제작 비용이 매우 저렴했을 것 같다.'],
#  [7,
#   "연극을 보는 듯한 영화. 극 초반에 다소 어색했던 연기들이 중후반으로 갈수록 조금씩 안정적이 되는 듯하다. 전반적으로 잘 짜여진 연기 합을 볼 수 있었다. 그냥 보다보면 '끼리끼리 만난다'는 말이 떠오른다. "],
#  [1, '지루하기도하고 내용이 너무 말도안되는..답답'],
#  [7, '.'],
#  [7, '이서진 정말좋아하는데 이번역은 잘안어울려요ㅜㅜ\n내용은 마지막반전이...'],
#  [3, '그냥 말장난 잔치. 몇번의 코믹요소외에 공감가는부분 하나도 없는 지들끼리 히히덕대는 노잼토크'],
#  [1, '그냥 막장... 스토리 전개도, 개연성도, 적응도 안되는... 이상한...'],
#  [8, '정직하지 못한 한국사회를 솔직하게 표현했다. 때론 비밀을 솔직하게 말할때 타인이 된 상대방과 자신을 뒤늦게 깨닫는다.'],
#  [1,
#   '나름 기대를 하고 봤는데... 나만 너무 옛날 사람인가? 보는 내내 짜증나는 영화였음. 어떻게 저렇게 비밀을 감추고 피곤하게 사는지 도저히 이해가 안감.'],
#  [7, '역시유해진 잼나다'],
#  [6, '유머가 있는 막장 드라마 본 느낌이다..'],
#  [8, '시대에 부흥하는 키워드\n\n말하고 싶은 부분에 대한 자극적인 소재가 다소 애매하지만\n그럼에도 한번 볼만 했다는 생각.'],
#  [3,
#   '기대많이 했고 엄청 보고픈 영화중 하나였다. 뒤늦게 봤지만 생각보단 별로였고, 욕설이 생각보다 난무해 너무 지겨웠다. 우리나라 영화가 보기싫은 이유중 제일 큰게 바로 육두문자 욕이다. 너무 힘들다. 가벼운 욕짓거리도 잇는데 왜 유독 육두문자를 쓰는지.....실생활 모임에서 욕 쓰는 경우 별로 없는데 어느 영화든 욕으로 장식 안 된 게 없다. 애들한테 우리나라 영활 못 보게하는 이유다. '],
#  [7, '저 나이 세대에 공감 가능한 얘기.. 재미있음'],
#  [7,
#   '나쁘진 않았는데 기대보단 다소 아쉽네요. 사람의 이기적인 본성을 현실감 있게 잘보여줬고 전체적으로 몰입도나 완급조절은 좋았습니다. 하지만 갈등을 증폭시킬수 있는 좋은소재인데 딱 기본만 표현한거 같고 그냥 익숙한 막장 드라마 본 느낌이예요. 시간 남으면 맘 편하게 보세요.'],
#  [6, '지저분한  사생활\n지저분하게 보여주기'],
#  [7,
#   '웃긴 부분도 있었고 공감되는 내용도 있었어요\n전체적으로는 모두 말못 할 잘못 하나는 가지고 있다는 고런 내용인데.. 그걸 너무 쎄게 설정을 했다고 해야될듯 합니다.'],
#  [8, '부모님이랑 엄청 재밌게 봤어요 추천합니당'],
#  [10, '걍 볼만한 수준이다가 1시간 지나서 유해진때문에 웃겨뒤진다 꼭 봐라 ㅋㅋㅋ'],
#  [7, 'tvN 드라마수준...'],
#  [7, '보이고 싶어하지 않는다면 보려하지 말자. 그것이 우리 삶을 파탄내지 않는다면...'],
#  [10, '신선하네요 '],
#  [5, '어수선하고 어색하고 불편하고 재미도 별로인...'],
#  [10,
#   '시나리오+연기파 배우+저예산, 이 모든 것들이 하나로 만들어진 영화, 너무 재밌어서 세번이나 봤네요.. ^^\n목소리 카메오 배우들도 나중에 알고 너무 짱이었어요~~\n\n학창시절 엠티때 마다 했던 진실게임...\n성인 아니 중년이 돼서 하면 절대로 해서는 안된다는 교훈적인 영화?? ㅋㅋ\n\n어쨌든 오랜만에 좋은 영화 봐서 반갑고 좋았습니다!!'],
#  [8, '모든 중년들이 충분히 공감하는 우리의 실상 !\n그냥 안고 살아가야 하는 ! \n까발려 좋은 것 없다는 !-.-'],
#  [10, '와 닿는 영화였습니다'],
#  [5, '너무 어거지스러운 설정에 자극적이다. 연기들은 좋네.. '],
#  [8, '너무 재밌고 웃겼음.끝난 후 생각을 하게 하는 영화.'],
#  [9,
#   '사람이 무엇인가에대해 생각하게 만드는 좋은 영화이다.   남은 안되도 나는 되는... 참 이기적인게 사람이라는 생각이 들었다.  소재가 자극적이긴 하나 영화이니까.. 그렇다고  해서 현실과 그리 거리가 멀지는 않고~  충분히 있을만한 일들이고 우리가 얼마나 진실되지 못한가 깊이 고민하게된다.  심리 좋아하는 사람이면 충분히 매력있는 영화인듯. '],
#  [7, '전개부터 결론까지 밋밋하고 찝찝하다. 그걸 원한 감독의 의도일지도. '],
#  [4, '연극이어야 할 소품들이 영화로 왔다. '],
#  [1, '보는 내내 불편했다.'],
#  [5, '연기는  다들   어색하고\n배경은 집구석  끝\n저비용  '],
#  [9, '웃으며 울며 긴장까지도 하게 됐던 영화, 잘 봤습니다!'],
#  [10, '최고의 서스펜스 스릴러\n혼자서 보길 잘 했다'],
#  [8, '초반에 이서진씨 연기가 좀 어색해서 웃겼지만 후반부로 갈수록 몰입되고 재밌어요. 열받으면서 보긴 했지만ㅋㅋ'],
#  [8,
#   '김수영 시인이 생각나네요\n\n영화 마지막 자막 우리네 3가지 삶을 하나로 통일하여 사는 사람 이 세상 과연 몇이나 될 까\n그런 완벽한 삶 아마 속세에는 단 한명도 없을듯 '],
#  [5, '생각보다 지루하고 부자연스러운 연기로 몰입이 안됨'],
#  [6, '나만의 비밀은 나 안에서 끝내는게 서로 좋다'],
#  [8, '때로는 나만의 비밀을 누군가 모르는게 서로에게 더 행복한것같다. 모든 사람이 전부다그렇다. 영화는 시간가는줄 모르고봤다'],
#  [7, '완벽한사람두없고 마지막 3가지삶 공감 \n폰 조심히 사용합시닷^^'],
#  [10, '핸드폰 무지 중요함...ㅋㅋ  \n시간 가는줄 모르고 봄'],
#  [10,
#   '사람은 누구나 세 개의 삶을 산다. \n공적인 삶, 개인적인 삶, 그리고 비밀의 삶... \n공감!! 사람은 그런 존재다..\n\n그렇지만 우린 서로의 비밀의 삶에 대해서는 적당히 모르고, 때로는 적당히 모른 체하고 살아간다. \n(누군가를 지켜주기 위해서, 아니면 현재 관계가 깨질까봐 두려워서.. 어떤 이유때문이든..)\n\n영화‘누구에게나 비밀은 있다’와 비슷한 느낌인데, 이 영화는 스마트폰이라는 소재가 주는 섬뜩함이 있다.\n스마트폰이라는 게 무서운 거다.........라는 생각'],
#  [8, 'Good'],
#  [5, '이서진하고 김지수하고 떡치는 사이란건 알지들??'],
#  [10, '도덕적 해이, 진실에 대한 두려움, 최소한의 양심이 만든 비밀들~~현실이기에 더 역겹다.'],
#  [3, '우리나라 사람들이 남의 사생활에 관심이 너무 많은것을 알수있네요..'],
#  [8,
#   '3가지 삶이있다는 메세지에 공감....실제 저런 상황이라면 떳떳할 사람이 과연 몇이나 될런지....어떤 이유든간에....마지막 반전에 대한 생각은 관객의 몫인가...ㅎㅎ'],
#  [2, '현실에 부정할수 없는 이야기들~ \n어제도, 오늘도, 내일도.....'],
#  [7, '예상외로 볼만함 이서진 연기가 넘 딸린다'],
#  [10,
#   '결말이 내가 원했던 바가 아니어서 조금 아쉬웠지만,\n영화는 시간가는줄 몰랐음....\n스마트폰 오픈게임, 진실게임\n이런거하면 안된다는 교훈???...ㅋㅋ'],
#  [10, '생각하게 만드는 영화'],
#  [4, '...'],
#  [8,
#   ' 최저비용에  가성비 제대로 뽑으셨네\n조폭재벌 얘기에서 드뎌 소소한 일상의 고통과 고민 그리고 행복에대해 대면하게 하는 영화 빵터졌음~'],
#  [7, '우리나라도 이런영화가 잘되는게 정말 시대가 바뀜을 알게해줌.\n나름 재미있게 봤음.'],
#  [8, '남편이랑 재미지게 몰입?하며봤네요\n빵빵터지는웃음도있고 현실감도있어서\n간만에즐거웠습니다'],
#  [1, 'ㅈ같'],
#  [9, '눈을 뗄수없을 정도로 몰입 하면서 봤어요'],
#  [10, '인간의 내면을 보면 다 이중적이다'],
#  [9, '유해진 간만에 까칠한 성격의 케릭을 하네요'],
#  [7, '영랑호에서 고기나잡자!'],
#  [7,
#   '개인적으로 한국판 완벽한 타인은 원작(Perfect Strangers, 2016 Italia)과 위험한 만찬(Nothing to Hide, 2018 France & Belgium)보다 보는 내내 몰입감이 좋았던 것은 정서적으로 한국인이기 때문이 크다. \n그리고~\n누구에게나 완벽한 비밀(Perfect Secret)은 핸드폰에 있다?\n그러나 그 완벽한 비밀은 공개적으로 스피커폰으로 공유해서는 안 된다. 네버~! '],
#  [10, '일단 재밌다. 거기에 가부장제 얘기, 성소수자 얘기를 잘 녹였다. 재미와 메시지 둘 다 잡은 영화.'],
#  [8, '유해진 염정아 최고. '],
#  [9, '재미 있어요 ㆍ'],
#  [9, '올해 본 영화중 가장 재미난 영화. 유럽 영화 느낌. '],
#  [9, '최근 본 영화 중 최고^^'],
#  [7, '가면속에 가려진 진실..\n배우들 연기가 다 좋네요-'],
#  [1, '이것도 영화입니까? 내가 발로 글을 써도 이보다 나을 듯. '],
#  [9, '졸잼이네 '],
#  [8,
#   '가장 완벽한 결합의 필요충분조건, 가장 완벽한 타인. // 그리고... 진정한 리얼 4DX영화! 이것이 가상체험의 결정판! 배우들의 한마디 한마디에 움찔거리는 관객들의 모습이란...'],
#  [9, '원작이 따로 있었군요 .. 그래도 수작(秀作) !'],
#  [3, '인셉션 오마쥬'],
#  [6, '예고편에서 나온 내용이 70퍼센트 정도 차지. 예고편을 안보고 봤으면 더 재밌었을듯.'],
#  [9, '훌룡함..\n쏘스도.\n내용도.\n연기도.\n배우도.\n트집 잡는놈이 병신임'],
#  [5, '그냥 유해진과 염정아의 노련한 연기만 좋았음 '],
#  [6,
#   '원작을 이미 본 상태에서 봐서 그런지 그냥 그랬음. 리메이크라기보다는 거의 모든 설정, 캐릭터, 스토리 심지어 대사까지도 다 똑같았음. 그냥 프랑스 원작 그대로를 한국배우들과 한국말로 통역해준 정도?? 원작을 안봤다면 재미있게 봤었을듯.... 근데 원작 본 사람은 좀 보면서 화남. 어떻게 그렇게 완전 똑같이 만들었냐....'],
#  [5, '씁쓸한 안방드라마...'],
#  [8, '리메이크의 어색함 빼고 나머지는 모두 좋았음'],
#  [8, '굳'],
#  [5, '리메이크가 아닌 카피 + 허세. \n결국 이름난 여러명의 주연들이 빛나는 막장 드라마일 뿐. '],
#  [1, '설정 자체부터 쓰레기..'],
#  [2, '인셉션이냐?'],
#  [9, '넘 리얼하고 마지막이 넘좋앗슴 허무하지만   다행이라는 안도'],
#  [10, '스케일이 크지않아도 재밌을수가 있다'],
#  [7, '누구나 겪게될수 있는 소재가 공감을 일으킴\n장소이동 없이도 스토리전개가 지루하지 않음'],
#  [8,
#   '참. 이런 막장영화를 봤나.... 그런데 난 별점을 8이나 준다.\n이연복쉐프가 짜파게티를 끓여서 고급 중식이라 줬는데, 미쉘린에서 별 5개를 줬네.'],
#  [10, '좋은 영화. 시원하게 벗은 영화.'],
#  [3, '그냥 어쩔수 없이 봣음'],
#  [9, '재미지네요\n간만에 9점드림'],
#  [9, '볼만함 '],
#  [8, '돈 찌끔들고 잘 만든 작품...시대를 대변하는 의미있는작품....염정아의 연기가 돋보이고 최고였씀..'],
#  [8, '이재규 감독 영화였구나.. 아...\n같이 본 동지가 각본 쥑입니다니다...\n잘 봤습니다..감독님.'],
#  [10, '재밌네요'],
#  [1, '드런영화.'],
#  [8, '겉면에 가려진 우리내 모습을 보는듯한 화려한 연출과 연기력...저예산으로도 이렇게 좋은 영화가 나올 수 있다.'],
#  [9,
#   '비밀 없는 사람없지만 그 비밀을 굳이 밝히지 않는게 좋을수도... 멋진 시나리오와 웃음과 감동, 교훈까지 얻을수 있어 좋았다.. 유해진, 염정아 커플의 명품 연기는 물론 배우들의 훌륭한 연기도 좋았고(딱한명의 약간 어색한 연기 빼고) 배우들의 출연료 외에는 큰 제작비 없이 이렇게 멋진 영화도 나올수 있다는것을 새삼 깨닫게 해준 영화...'],
#  [10, '웃으면서 잘봤습니다\n10점드립니다.'],
#  [10,
#   '오랜 만에 잘 만들어진 영화를 봤다. 핸드폰 공개를 통해 밝혀지는 40년 지기 친구들의 낮선 모습. 뒷담화, 불륜, 게이 등의 극히 개인적이고 비밀스런 이야기들이 공개되면서 영화는 충분히 긴장감과 흡입력을 제공하고 있다. 감독의 재능과 성실이 느껴졌다.'],
#  [10, '재밋게봤어요'],
#  [4,
#   '이게 잼있다라....  불편한 억지 스토리 전개에 배우들은 의미없이 버럭버럭 맥락이 없음 그냥 킬링타임용 영화. 배우들의 연기력이 아까운 영화'],
#  [10, '씁쓸하게 재미있었다'],
#  [0, '원작을 먼저 보고 이 작품을 보니 이 작품이 너무 허접하다는 생각이 들었습니다.\n돈과 시간이 아까운 영화.'],
#  [6, '막장인 듯 막장 아닌 막장 같은 억지스런 영화'],
#  [9,
#   '이서진 연기 어색하다고들 하더니 뭐 딱히 그런건 없는거 같고\n다들 연기는 잘하는 사람들이라 나쁘지 않았다.\n지루하지도 않았고, 몇번 크게 웃기는 상황도 나오고,\n이 정도면 충분하지. 왜들 최악의 영화라고 하는건지....'],
#  [0,
#   '내생의최악의영화....평점 쓰려고 들어왓습니다...................동성애문제...바람... 성관계...\n어릴때 친구들이 커서 만나서 핸드폰으로 오는 문자와 전화 공유... 그런데 그것들이 모두 다 헐뜯고 바람피고 성관계하고 동성애... 결론은 사람들은 다 세가지모습이있다..... 이런 영화 다시는 만들지 마세여 제발..... '],
#  [0,
#   '0점..... 평점 쓰려고 컴퓨터 켰습니다. 보는 내내 뛰쳐나오고 싶었고, 들인 돈과 시간이 너무나 아까웠어요. 지인들과 가서 할 수 없이 참고 앉아있었는데, 끝까지 실망만 주네요. 여자들은 사람 없는 곳에서 서로 험담하고 남자들은 여자 무시하는 맛에 사는 것 같고 바람피우고, 특히 친구 아내랑 바람나고... 아이고, 영화 본 후 넘나 씁쓸하네요. 가장 나빴던 건 알맹이가 없는 영화라는 점....'],
#  [5, '몰입도, 연기력은 외국버전이 훨신 좋았음. 이서진 웅얼거리는 말투가 좀 어색했고, 염정아는 역시 짱짱걸. '],
#  [8,
#   '남자는 안드로이드폰, 여자는 아이폰. 영화의 구성이 참신하다. 조금 매끄럽지 않아도 다 이해할만큼 참신하다. 사적인 삶과 은밀한 삶을 까이면 공포가 된다.'],
#  [1, '억지 미화시키는 느낌'],
#  [8, '재밌었습니다'],
#  [8,
#   '거의 똑같은 내용의 외국버전 먼저 봤었는데  한국판도 나쁘지 않네요\n누구나  말못할 비밀은 있나봅니다\n나만 너무 깨끗하게 사는거 같네요 ㅋ'],
#  [6,
#   '이서진 연기 못하고 이상하다는 댓글 겁나 많아서  얼마나 이상한가 봤더니 배우들 연기 다 잘하던뎅~~~ \n반전이나 좀 쇼킹한 에피소드를 기대했는데 끝까지 밋밋하고 잔잔하고 지루.\n충분히 일상에서 일어날수 있는일들.'],
#  [8,
#   '스토리 괜찮.\n유해진 연기가 왜 좋다는 지 이해 안감. \n유해진, 조진웅은 매너리즘에 빠진듯, 식상함.\n이서진은 자연스럽네요. \n추천합니다.'],
#  [6,
#   '기대안했는데, 좀 유치하고 막장스럽긴 했어도 나름 가볍고 유쾌하게 보았음. \n약간 연극적인 느낌도 나고,\n역시 연기는 유해진이 갑이네~'],
#  [8, '막판에 불편했다. 아쉽다.'],
#  [0, '최악 쓰레기영화'],
#  [9, '흥미로웠습니다. '],
#  [3, '조금 웃기긴한데 불편…반전이 있나 기대를 했지만~그냥그냥'],
#  [9,
#   '2편이 만들어 진다면, 친구의 아내도 사랑하고, 친구의 딸인줄 알았던 자신의 딸도 사랑하는 개막장이 탄생할 수 있음. 인생사 요지경.'],
#  [9, '괜찮네요 유해진씨 연기 정말 기가 막히게 웃었네요 뭔가 시사하면서 코미디로 소화하면서 생각에ㅜ남기게 하네요'],
#  [6,
#   '저의 점수는요, 딱 6점이 적당하다 봅니다.ㅎㅎ\n그렇게 재밌지는 않지만 집중하며 보게 만드는 소재.  유해진이  잠들기전에 날 웃게  해주네요.ㅎㅎ  그런데,염정아가 얼굴이 아파보이는데 \n저만  그렇게 보는건가요? '],
#  [8,
#   '볼만합니다. 특히 유해진의 연기... 밤에 누워서 집중하면서 봤는데 나도 모르고 크게 웃었네요..  웃음뿐만 아니라 현재 우리들에게 무언가 교훈을 알려주는 영화ㅎ 추천합니다.'],
#  [9,
#   '되지도 않는 영화 백개 보다 이런 영화 한두개가 훨 낫다. 스토리, 연출 다 괜찮았고 재미도 있음. 다만 이 영화를 잘못 해석하고 이해하면 안본것만 못함. 세상엔 감춰져야할 비밀이 있고, 감춰지는 비밀이 있다.'],
#  [8, '시간이 훅~\n잼나게 봤어요'],
#  [0, '최악!!쓰레기 영화.'],
#  [10, '재밌어요'],
#  [9, '너무 재밌어요.... 상황 상황이 너무 웃기고.. 대락 난감한......'],
#  [9,
#   '우와...영화 잘만들었다.. 리메이크 위험한 만찬을 보고난 후에 본건데도 더 재미있다. \n말빨로 조지는 영화임에도 불구하고 상황 상황이 재미있고 신박하다. 배우자들 특유 캐릭터도 잘 표현됐고, 하드웨어 소프트웨어 모두 구성을 잘한것 같다. 역린은 그닥이었는데...감독 다시봐야 할듯.'],
#  [8,
#   '코믹 스릴러라고 해주세요 .. 나만그런가. 손에 땀이다나네요 ㅋㅋ \n그리고 별점 한개주는 색이들은 머냐.... 이정도 작품이면 별점 8개이상은줘야지'],
#  [10, '굿'],
#  [9,
#   '정말 재밌게 봤습니다..\n염정아님 연기는 이제 신급이네요\n세경역 하신분은 강혜정씨 닮았네요\n이서진씨가 저런 연기한게 첨인거죠 ㅎㅎ\n연기변신 성공'],
#  [2, '아~  작위적이고 합맞춘 대사... \n\nPPL도 적당히 해야지 너무 작위적이잖아.\n\n보는 내내 짜증난다. '],
#  [10, '영화에서 정답을 찾을려고 하네 그냥 웃고 즐기고 영화를 보고 좀 생각을 하면 됐지! 좋은 영화네요!'],
#  [8, '아주 재밌게 봤습니다.'],
#  [8,
#   '중후반 클라이막스 부분에서 너무 연극톤 분위기..\n\n염정아씬이 그렇게 롱테이크로 끌고갈 일이었나 싶고\n\n그래도 소재의 특이성과 코믹함이 지루하지 않게 해줘서 볼만했음'],
#  [10, '잼있음 간만에 많이 웃었음     '],
#  [10, '오랜만에 너무 재밌게 본 영화'],
#  [8, '흥미로운 소재였으나 너무 진부한 주제였음. 누구에게나 비밀은 있고 판도라의 상자를 열지말라는 교훈을 잘 포장한 영화였다.'],
#  [8,
#   '제밌긴 한데.. 마지막 부분 편집이 아쉽네요..\n여기 댓글보고서야 인셉션 패러디인줄 알았다..\n반지가 오래도 돌아간다 싶더니..\n역시나 내 염려처럼 엔딩부분 이해 못하고 결말을 오해한 관객들이 꾀 있는듯..'],
#  [9, '한국인의 정서와 잘어울리는 한국인 이라면 흥미있게 볼 영화 '],
#  [6, '케이블에 나오면 편하게 볼 영화. 돈주고 보기에는 조금 아까운 듯~'],
#  [9, '올해 본 영화중에서 제일 괜찮은 듯\n남녀관계라든지 인간의 이중성, 허위의식 등을 재미있는 대사로 잘 다룬듯'],
#  [5, '줄거리 설명하라하면 5분안에 할 수 있음. 평점 은근 좋을 때 봤는데 지금 평점이 적당하네요. 7.6'],
#  [6,
#   '인간의 본성을 잘 드러낸 영화,,,좀 애매하지만,,호불호가 갈리는영화,솔가 200만정도가 적당한 영화,,,,근데 이서진과 김지수가 그런 관계란 점 에서 깼다,,'],
#  [8,
#   '일상에서의 심리를 잘 이용한 영화\n한 공간에서 비밀이 파헤쳐지는 내용\n신선했어요.\n시나리오가 훌륭했던 영화~~재미지네요.\n\n이서진씨 연기는 이상했어요.\n욕하는것도 대사치는것도 삼시세끼 느낌.'],
#  [6,
#   '간만에 한국영화 볼만했네 근데 좀 웃긴게 감독이 의도한 것인지는 모르겠는데 제일 불쌍한 남녀 제일 뻔뻔하고 가식적인 남녀 이렇게 캐릭터가 잡혀있네'],
#  [0,
#   '코믹이라 기대를 많이 했는데 막상 코믹 부분은 없고 민망한 대사 장면이 너무 많이 나온다\n\n마지막에 갑자기 부부들이 화해한것도 어이 없었다\n\n그럴꺼면 싸우게나 하지말지\n\n욕하고 싸우고 그러다가 뜬금없이 화해?\n\n영화를 15세가 아닌 19세로 등급 올리는게 잘 어울릴듯\n\n이런영환줄 알았다면 안봤는데 '],
#  [6, '이서진은 왜케 어색하냐'],
#  [0, '개 같은 쓰레기 영화네....\n부부나 커플끼리 이거보고 \n많이들 싸우겠군....'],
#  [0, '이런 쓰래기 같은 영활\n더러운영화구먼'],
#  [7,
#   '이영화를 만든 감독은 천재다.\n이영화의 제작비 대부분이 배우캐스팅에 썼다는걸 알게한다.\n그리고 집한채빌려서 영화의 2시간을 다체운다.\n그래서 이영화의 감독은 천재다.'],
#  [8,
#   '두꺼운 얼음을 뚫는 첫장면, 안과 다른 밖. 월식으로 가려도 드러나는 사람의 본성. 그리고 세개의 삶. 그래서 우리는 완벽한 타인인가 보다. 그렇게 삶은 흘러간다. 강물처럼.'],
#  [9, '장르가.. 호러 ? 공포 ㅋㅋ'],
#  [10, '지루할틈이없네요\n리얼현실영화~재밌어요'],
#  [9, '코미디이기도하고 스릴러이기도하고 서스펜스이기도한 퍼팩트한 이야기,반지가 돌아가는것으로 레드선~~~~'],
#  [1, '억지 그런 이야기'],
#  [4, '막장 영화. 막장 드라마가 영화관으로...ㅉ'],
#  [9, '재미있게 잘 봤습니다. \n좋아하시는 분들만 다 나오셨네요. 다들 파이팅!!'],
#  [10, '유해진씬이 너무 재미있었다'],
#  [5, '원본이더재밋다.폰까기 놀이한것도 아니네'],
#  [7, '프랑스 리메이크판 보단 초반에 정신없고 산만했지만 괜찮게 진행되네요 재밌게 잘 봤어요 '],
#  [4, '결말이ㅋㅋ 이해가좀안되네 잘보다가 허탈한느낌'],
#  [9, '좋던데\n\n공적인 개인\n사적인 개인\n비밀의 개인'],
#  [9, '살짝 부족하지만 재밌슴'],
#  [4, '프랑스영화 리메이크 했다는데\n그 영화 자체가 설정이 억지스럽고\n별로 유쾌하지도 않음. '],
#  [10, '정말 연기들 너무 잘한다. 역시 베테랑들.'],
#  [9, '간만에 현웃터지면서 봤던영화'],
#  [8, '영화내내 헉!!하는 설정이 많아서 몇번은 \n나도 모르게 소리 지르면서 봤음. \n넘 웃기기도 했고 지루하지 않게 봄. '],
#  [1, '멀리 영화관까지 가서 돈내고 2시간  앉아서 보기에는 지루.\n안방에서 드라마로 보기에 적절. '],
#  [6,
#   '재미있는 요소도 몇가지 있긴 했지만, 보는 내내 기분이 별로..\n부부마다 불륜에 이혼 직전의 아슬아슬한 상황\n정상적 가정이 없는 친구들의 모임. \n친구인게 이상하다'],
#  [1, '보고 나서 기분이 별루인 영화다'],
#  [8,
#   '아주 환상적인... 최근 이런 영화는 첨인 듯 하네요. 사람의 마음은 어디까지 공유 할 수 있을까?  초반 정신없이 쏟아지는 말빨들... 이게 뭔가 했다가 점점 감정들이 엮기면서 만들어지는 갈등, 에피소드... 한마디로 출연료 빼면 돈들지 않았을 것 같은 영환데 소극장 연극보는 듯한 몰입감... 그리고 반지의 마법, 반전이다. Very good.'],
#  [1, '이도 저도 아닌... 영화? 그냥 티브이에서 보면 딱인 영화'],
#  [10, '사람 심리를 섬세하게 느리고 현실적으로 표현한  영화..재미도 있고 생각해 볼 점도 많고 코믹 영화지만 여운이 남네요.'],
#  [9, '약간 작위적이긴 하다만 한국 영화에서 새로운 시도라 좋았음'],
#  [5,
#   '연기자분들 연기력 때문에 5점.\n중간까지 잘가다가 엔딩으로 갈수록 산으로 감.\n반전이라고 넣어놓은 엔딩은 반전처럼 퐉 오는게 없어서 옆에 커플 계속 잉?? 잉?? 거리고있음 ㅡㅡ\n코미디로 가려면 계속 코미디로 가는게 좋았을건데 코미디면서 교훈을 주려고 급한 마무리를 지어 반전도 뭣도 아닌 이상한 엔딩을 함.\n그래도 하나 망치맞은건 니들도 날 이해를 못하는데 엄마(부모님이였나)는 이해하겠냐??였나? 그 대사..\n아.. 했음.\n그분들의 현실을 좀 더 느끼게 된..\n암튼 그 게임을 왜 하자고했는지 그 의도가 심히 기분 나빠지는 영화임.\n왜 하자고한거냐 뭘 잘했다고 !!!\n이서진 연기 혼자 못함.\n4점줄까 하나가 다른분 생각해서 5점.'],
#  [10, '영화잘받습니다 \n스토리도 탄탄하고 재미도 있었어요\n공감할 수 있는 이야기도 많고 좋은영화였습니다~\n '],
#  [1, '6점!'],
#  [10, '핸드폰이라는  소재로  이렇게  재밌다니 한참을 웃었었다ㅋㅋㅋㅋㅋ배우들연기도 너무좋았고~'],
#  [8, '투자비 대비~\n연기~ 연출이 모두 좋았다.\n현대인들의 스마트폰으로 고스란히 웃지못할 애환이 담겨있네요~ ^^*'],
#  [9, '치밀하고\n웃기고 시원한\n완성도 높은 최고의 영화'],
#  [7, '전반적으로 그저 그런 영화'],
#  [8, '누구에게나 비밀은 있다.'],
#  [9, '극본 ,연기 모두  좋았어요'],
#  [9, '재미있고 노골적이고 생각하게 만드는 영화'],
#  [9, '각본으로 승부 보는 엄청난 영화'],
#  [9, '어쩜 내모습이 아닐까 싶었네요.\n굿~~!!!'],
#  [10,
#   '우리들의  현실속으로  들어간 느낌 이랄까요\n그보다는  조금 과장된 내용이었지만\n이런  아이템으로도  영화를  만들수있구나~\n생각했어요~\n넘넘  재미있었고 요즘 소리내어  웃어본게  얼마만이었던지\n집에  도착했는데도  웃어지네요~~~\n나도 비밀이  있나 ~?생각해봅니다~'],
#  [9, '대본도 배우들 연기도 너무 좋았어요~\n유해진님은 역쉬~웃다가 나왔어요~'],
#  [9, '넘 재밌게 봄ㅋ\n배우들 연기가 좋았음'],
#  [2,
#   '이서진ㅋㅋㅋㅋㅋ연기보고 빵터졌넴ㅋㅋ\n진정한 빌런이다\n유해진이랑 삼시세끼보는줄\n조진웅 연기도 오그라든다\n기대했는데 결말이 고구마넴\n대사는 또 왜케 구린건지 ...'],
#  [9, '현대사회에서 일어날수있는? 에피소드?\n일상생활속 모습을 디테일하게 잘 표현한듯합니다\n재미있어요~'],
#  [5,
#   '스토리가 재밌긴 한데\n19금 영화 아닌가요?\n너무 대화가 청소년이 보기엔 적나라 하던데\n애들이랑 갔으면 분위기 이상할거 같애요\n누가 15세 이상으로 결정 한거죠?'],
#  [7, '재밌게 봤네요.  스토리 설정이 기발하고 제각기 비밀을 가진  엉큼한 남.여.ㅡ암튼 너무 웃겨서 박장대소 했습니다.'],
#  [6, '웃긴장면 몇개 빼고\n앤딩을 왜 그렇게 했는지 잘 모르겠다..'],
#  [9,
#   '안보고 평점 단 사람들이 있는데, 보고 평점 좀 답시다. 계속 웃다가 끝나고 영화관 나왔어요.  재밌어요. 보고 판단 합시다 ㅋㅋㅋ.  누구나 공감할 수 밖에 없는 상황... 뭐 이런 저런 작은 공간안에서 펼쳐지는 심리 상태등... 전 간만에 되게 편하게 웃고 나온거 같네요.. 재밌어요. 아래 개소리는 즐이고요 ㅋㅋㅋ... '],
#  [7, '영화 싸게잘만들었음'],
#  [8, '남녀의 모든 것\n\n관계의 모든 것\n\n심리의 모든 것\n\n이 영화로 충분하다'],
#  [10, '박경주..\n바본가?   영화를 이해못했네..'],
#  [2,
#   '구성이 완성도가 떨어짐.\n이서진. 바람피운 여자가 임신했다는데 끝마무리는 부인과 해피엔딩.\n유해진. 친구핸폰바꾸어 게이라고 오해하는데 끝마무리는 부인과 해피엔딩.\n성형외과 의사친구 이서진과 그의 부인이 불륜인데 끝마무리는 해피엔딩 등등\n도저히 이해가 안가고 해명도 없이 왜 이리 짜임새가 엉성한지...시간과 돈이 아깝다.'],
#  [9,
#   '원작인 퍼펙트 스트레인저스보다 훨씬 깔끔하다.\n훌륭한 시나리오, 깔끔한 연출, 과하지 않은 연기, 편집 또한 나무랄데 없다.\n올 한해 한국영화의 가장 큰 수확이라 할 만하다.'],
#  [8, '현실에 잘 짜여진 모습.\n현실과 사이버 상의 문제를 잘 드러내고 있다.'],
#  [10,
#   '하도 사람들 입에서 돌고돌아서 궁금해서 어제 봤는데\n그럴만한 이유가 있었습니다\n재미있었어요\n크리스마스때까지 끌고가면 800만은 그냥 넘길듯'],
#  [9, '기대없이 봤는데  진심  잘만들어진  영화.'],
#  [8, '꼼꼼한 디테일  작가의  승!'],
#  [1, '볼까말까 생각중임  많이츱네요'],
#  [3, '원작보다 못했으며 아이디어 몇개로 포장만 했다.'],
#  [8, '.'],
#  [10,
#   '배꼽 빠질 정도로 웃고 나온 영화..\n웃기기만한게 아니라..뭔가 공감도 되고..\n영화속 부부들이 나랑 동갑으로 나와서 더 공감됨..'],
#  [10, '긴장감 있고 재밌게 잘 봤어요'],
#  [9, '완전 배꼽빠지게 웃음. 영화관 내에 웃음소리가 넘쳐남. 올해 본 코미디 영화 중에 제일 재미있었음!!!'],
#  [8, '볼만했음.\n나는 무얼 숨기고 있을까? ^^'],
#  [9, '오래간만에 재미있는 영화 봤습니다. '],
#  [8, '관계가 참 복잡하다 복잡해. 내가 이래서 결혼을 안한다.'],
#  [8, '어리다면 이 영화를 이해하지 못 할 것이다'],
#  [7, '이서진 연기가 거북한거(심히 부자연스러움) 빼고 괜찮음'],
#  [10, ' \n재밌어요\n스토리도 있고\n많이웃었네요'],
#  [1,
#   '배우들 얼굴에서 세월의 무게가 느껴져 가슴 아팠고 연륜을 생각하면 연기를 기대했지만 역할들이 맞지 않는 역할들을 맡아서 부자연스러운 대사와 딕션, 갑분싸 감정 연기 그리고 역시 정상적인 직업의 역할은 소화 못하는 유해진,꽃보다 할배를 찍다가 바로 온듯한, 연기가 안되니까 쌍욕으로 커버하려는 이서진,혼자 1인 연극톤연극하시는  조진웅까지 저 배우들을 도와주는 한국관객이 너무 위대해 보인다 이탈리아 영화를 리메크하면서 한국식 정서로 변환 시키지못한 감독의 무능함과 억지스러운 오프닝과 공감이 떨어지는 느낌으로 만들어버린 너무 멍청한 연출의 가치관이 도무지 이해가 안된다 역린감독이라 그래도 좀 기대했건만 이건 충격이다 마무리에 뭔 훌륭한 진리라도 알려주는것처럼 겉멋을 부리더니 결국 천박하게 마무리해버린다\n500만'],
#  [6, '뻔한 인물, 뻔한 전개 지루했다. '],
#  [10, '잘 봤습니다.'],
#  [1, '돈과 시간이 너무 아깝다'],
#  [1, '관객을 모독한 저예산 영화.....이혼가정 많이 늘었을 듯...앞으로 영화 만들때 돈좀 써라...'],
#  [2, '보고나서 왠지모를 기분 나쁘고 짜증나는 영화 \n유해진 부부빼곤 볼것없는 영화'],
#  [10, '7.6이라고 장난함???'],
#  [10, '난 잼든데'],
#  [10, ' 친구 4명이서 봤는데 진짜 재밌게 봤습니다.'],
#  [9,
#   '조금만 어긋나도 억지스럽고 작위적으로 느껴질 수도 있는 소재와 내용인데\n무난하게 잘 풀어냈네요. 한국 영화 답지 않다라고 생각했는데 \n원작이 따로 있나봅니다. '],
#  [10, '이것이 인간이다. 사회적관계이고, 가면을 쓰고 살아가는 우리의 모습이다'],
#  [9,
#   '한국 블랙 코미디 사상 최고의 영화로 평가할수 있음.. 감독의 전작이 역린이라는 사실이 믿기지 않을 정도로 연출도 군더더기 없이 깔끔했고..  배우들의 연기도 좋았고 시나리오 각색도 어색함 없이 한국화 되어서 이질감도 없었고.. 두시간 동안 정말 즐겁게 영화 볼수 있었고 현대인들의 사생활을 잘 들여다 보게 해준 영화였슴.. 최고..'],
#  [9,
#   '다 잡은 영화, 8점 9점중 고민하다가 염정아의 연기와 (다들 잘 했지만) 김지수의 몰아 넣고 싸대기와 욕에 9점. 시원했음. '],
#  [10, '이 영화 이유없이 뱔점테러하는사람들은 \n이거본 후로  연인이랑 해어진거임?? ㅋㅋㅋㅋ'],
#  [10, '볼때는 배꼽잡으며 웃었는데..보고 나서는 와~~무섭다...라고 느낀영화'],
#  [8,
#   '현대인들의 속물적인 이중생활을 만천하에 공개해서 보는 관객들은 불편했을수도 있겠지만 그렇기 때문에 더 가치가 있는 영화였습니다 러닝타임이 조금 길게 느껴지기는 했는데 스토리를 이끌어나가는 방식이 새로운 시도였다는 점도 좋았고 배우들 연기도 전반적으로 코믹했어요'],
#  [9, '웃다가 영화끝남'],
#  [6, '이재규 감독님 언제나 존경합니다!!!! 평소 ㅗ팬입니다! 완벽한 타인 화이팅!!!!!ㅋㅅㅋ 이재규 감독님 화이팅!!'],
#  [10, '재미있는 영화'],
#  [1,
#   '한마디로 영화의 기본 구성요소를 무시한 단편영화.\n영상, 음악 그리고 음향 무시...\n오직 대화만 있었고.. 그것도 코메디적인 아주 얕은 대화들..\n아바타 같은 영상미와\n보헤미안 랩소디 같은 음악, 음향은 아니면\n입장료를 싸게 받던지...\n정말 관객을 우습게 아는것도 아니고 너무나 불쾌 했던 영화같지 않은 영화.\n단편 영화제 출품이 어울린다고 할까?'],
#  [9,
#   '아무 생각없이 아내 때문에 보게 되었습니다. 근데 너무 재미 있게 봤습니다. 지금 옆에 있는 아내를 더 아껴주고 사랑해주고 그리고 외롭지 안하게 해야 겠다는 생각이 들게 만든는 영화였네요'],
#  [10, '진짜 재밌어요 인생영화입니ㅇ다ㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  [9,
#   '40대 기혼여성으로 실감나게(?) 봤습니다!\n심각함과 웃음을 왔다갔다 하며 현실을 풍자한 재미난 영화였네요~ 유해진씨 염정아씨 연기 참 좋았어요.. 결론은 서로의 핸폰은 안보는게 상책ㅎ'],
#  [8,
#   '저는 재미있게 봤습니다 ~ 관객들도 많이 웃고 ~ 제법 괜찮은 영화인건 맞습니다 .. 원작이 궁금해지기도 하고요 ~아마 결혼한 사람들에게 더 공감이 될듯 한 영화에요...마지막 결말이 재미있게 처리되어서 생각을 많이 하게 하기도 합니다...다만 ㅎㅎ 배우 평을 하는것은 그렇긴 하지만...이서진씨는 평소 멋있는 역할만 해서인지 이런 역에 딱 맞아 보이진 않았지만 ...그렇다고 연기를 못했다는 것은 아닙니다~ 다만 조금 어색한 감이 없지 않았습니다  ~ 근데 보고나서 왠지 좀 뭔지 모르게 쓸쓸해지는 것은 저도 유부남이어서 일까요 ㅎㅎㅎ 마침 집에서는 ⟨그는 당신에게 반하지 않았다⟩ 를 하길래 봤는데  그때문인지 더더욱 ~ㅎㅎ 암튼 볼만합니다~ 근데 이런 영화 사람 적을때 보면 재미없을지도 ㅎㅎ 재미있는 영화도 '],
#  [7, '테스트~한번더!'],
#  [10, '너무 즐겁게 본 영화'],
#  [10, '너무 재미있거 봤네요'],
#  [8, '간만에 많이웃고  생각하게하는 영화였어요.^^'],
#  [10, '연기 다들 능청스럽게 잘 하네요\n큰 교훈이 있지는 않았지만\n재미있게 봤어요 ㅋㅋ '],
#  [6, '그냥 재미로 보는 영화입니다.'],
#  [8, '기대 보단 좋았던\n연기력 누수가 없음\n프랑스 영화인데 재미 있는 버전 ..'],
#  [4, '친구랑 재미없다고 나왔는데\n평이 많이다르네요'],
#  [10, '아무 생각없이 보러 갔는데 무지 재미있었던 영화!\n웃음 참느라 혼났음. '],
#  [10, '완전두시간 웃다옴  생각없이 보다가 \n스트레스 풀고왔슴'],
#  [9, '정말재밌게봤어요ㅎㅎ'],
#  [3, '좀 짜증나는영화 ᆢ 처음부터  설정티가 ㆍㆍ재미없음'],
#  [10,
#   '모처럼 영화다운 영화를 본 듯~~\n두 시간이 어떻게 가는 지도 모르게 다 가버렸네.\n인간의 내밀한 심리를 무리없이 충분히 있음직한 이야기들로 지루하지 않게 풀어내는 능력~~~\n마지막 반전 또한~~~~^^\n실컷 웃다가 보니 뭔가 하나가 가슴에 자리잡은 느낌~~~\n짠한 여운 같은 것~~~'],
#  [8,
#   '오랜만에 이야기의 힘으로 끌고가는 영화를 본거 같음. 현실성이 없을 수도 있는 상황으로 인물들을 끌고가는데 전혀 무리함이 느껴지지 않았음. 두고두고 봐도 재미있을 영화'],
#  [7, '삶은 하나가 아니지. 둘 이었다가 셋 이었다가\n다시 또 하나여야만 하는 인생'],
#  [10, '진짜 잼있어요 ㅋㅋㅋ'],
#  [10, '오랜만에 진짜 괜찮은 영화'],
#  [8, '유쾌하네요\n누구나 비밀은 있고\n그 비밀은 지켜 주자구요 ^^'],
#  [10, '재밌었어요. '],
#  [2, '돈안들고 코푼영화  나오는순간  스토리  싹 사라지는  그런영화 너무합니다 왜갔을까 영화보러 ㅠㅠ'],
#  [10, '연인들 필수관람'],
#  [9,
#   '평일 밤 늦게 보러 갔었는데 생각보다 사람이 많더라구요.\n군데군데 다들 웃음터져서...ㅎㅎ \n별 생각없이 잘 웃고 잘 보고 왔습니다.\n사실 이서진 보러 간건데 캐릭터가 영... 맘에 안들더군요 ㅋ'],
#  [5, '이탈리아 원작 위험한 만찬 추천드립니다'],
#  [10, '굿굿'],
#  [7, '이탈리아 원작을 보고 싶다.'],
#  [10, '오랫만에 시원하게 웃다왔어요!\n또보고 싶은 영화!'],
#  [1, '평점에 완전  낚인 영화...ㅜㅜ'],
#  [10, '.'],
#  [9, '상당한 수작이었어요'],
#  [9, '소리내서 깔깔깔  웃어보기는  간만~~ 잼나게 봤음'],
#  [7, '사생활은 서로 모르는게 약이다.\n부부간에도 비밀을 알면 타인이 된다.'],
#  [8, ' 이 시대를 그린 영화한편 잘 봤읍니다\n우리의 현실을 그대로 들여다 보는 느낌//\n많이 웃고 재미있게 본 영화입니다'],
#  [8, '식사테이블에서 영화 한편이 나올 게 있을까 싶었는데 생각보다 지루할 틈없이 재미있었음~'],
#  [8, '인간의 속을 까보이는 시나리오\n연륜이 느껴지는 연기\n원작을 능가하는 세밀한 연출력'],
#  [1, '보지마세요~~~~~~~\n아마추어영화~~~~~~~'],
#  [10, '간민에  잘 만든 영화'],
#  [10,
#   '완벽한타인 아주 재미있게 봤다\n우리 게임 한번 해볼까\n다들 핸드폰 올려봐\n저녁억는동안 오는 모든걸 공유하는거야\n카톡 문자 이메일 전화 할것 없이싹'],
#  [9, '연기호흡이 아주 좋았고 마지막이 반전이네요'],
#  [10, '일단 보면서 한껏 웃을 수 있음. 기대하지 못했던 재미가 있음'],
#  [10, '색다르고 재미있었다. 그런데 평론가들은 짜다. 왜 그렇지? '],
#  [9, '시나리오가 완벽해보임\n여자들의 미묘한 갈등 감정의 흐름\n사회문제와\n부부문제\n자식문제들도 같이 볼수 있음'],
#  [1, '.....'],
#  [10,
#   ' 어쩜 배우 한 명 한 명 연기를 그렇게 잘하시는지.. 진짜 너무 재밌게 웃으면서 봤습니다. 근래에 한국영화보면 너무 잔인하고 욕도 많아서 보고나도 찜찜했는데, 기대 하나도 안하고 그냥 봤는데 정말 재밌게 봤네요'],
#  [10, '영화관에서 이렇게 크게 웃어본것도 첨이네\n그냥 생각없이 보면 잼있슴\n웃지못하는 사람은? \n이유가 있겠지 ㅎㅎㅎ'],
#  [9, '맛깔나게 인물들의 갈등들을 그려내면서 마지막엔 인간의 삶을 고찰하게 되는 영화'],
#  [2, '보지마.'],
#  [9, '잼나게봄'],
#  [10, '완전 공감하면서  긴장되면서 꿀잼'],
#  [8, 'ㅋㅋ 불륜들 이거보면 대박'],
#  [10, '여기서 기분 나쁘면 그런 사람'],
#  [9,
#   '재미있게 잘봤어요.. 이서진하고 김지수 말고는 다들 연기도 잘하고.. 일단 내용이 맘에 듬!! 요란한 장면도 없고, CG도 없고 그래도 보는내내 집중하게 만들고 생각하게 하는 영화였음.. 적당히 웃기고 적당히 심각하고  적당한 반전을 주고, 감독님 능력자 인듯... 기혼 친구들한테 꼭 소개해주고 싶은 영화임.. 간만에 재미있는 영화봤어용~~'],
#  [10,
#   '큰 기대없이 갔다가\n장내에서 그랗게 수다스럽게 웃어보다니\n스트레스  발산하고 왔어요!\n출연잔 각자의 역활 조으시고\n서진씨 아찔함에 기절합니다 ㅎㅎ'],
#  [4, '평점보고 기대해서 그런지 생각보다 별로..\n그냥 시간때우기용 정도'],
#  [10, '넘 재미있어요!!!'],
#  [1, '추천  하고 싶지는  않은  영화'],
#  [9,
#   '엄청난  투자작품은 아닌듯한데\n그 짜임새와  배우들의  연기가\n지루할 틈이없이 우리삶의 내면을 헤집는\n그리고 있는 그대로의 모습들을 인정하고\n다시 보듬고  살아가는\n친구같은 우리모두의  인간관계가 \n그리고 삶이 좀 더 편하게 느껴지게한다'],
#  [9, '완벽한 코메디.\n현실에선 날선 신경전.'],
#  [9, '무조건 강추'],
#  [9, '시간가는줄모를정도로 잼남'],
#  [6, '도입부\n애들분이 좀 식상'],
#  [3, '완벽한 타인이 먼저냐\n넷플릭스에서 본 위험한 만찬이 먼저냐'],
#  [4, '이거보고나면허탈함 \n괜한 가정 불신일으킬수있음\n\n  막장중 막장'],
#  [7, '나는...........다른사람에게 추천하고싶지는 않음 ㅋ'],
#  [5, '어처구니 없게 웃긴건 가끔 있는데.... 지루하고 남는 생요이 없음'],
#  [7, '순간순간 빵빵 웃음 터지기는 했으나\n다소 지루함'],
#  [7, '몰입감은 높은 편인데 보고나선 아무것도 남지 않는 영화.\n너무 뻔해서 기분 나빠지는 영화'],
#  [0, '너무쓰레기같은 영화'],
#  [7, '무난하게 재미있네요 아이디어가 신선했고 웃고 나왔네요 ㅎ'],
#  [7, '시간이 가면 숨길것도 늘어나기 마련 ㅋㅋ 오래산 사람일수록 보는내내 불편해지는게 코미디인 영화 '],
#  [8, '괜찬은영화\n볼만하고 아이디어 좋네요'],
#  [10, '보고싶다'],
#  [9, '잘 만든 영화다...'],
#  [10,
#   '정말 오랜만에 작품성 탄탄한 한국영화 한편 봤네\n짜임새 있는 시나리오와  배우들의 명품연기\n나름의 긴장감과 배꼽잡는 웃음의 연발타 그리고 그 안에서의 주는 감동 많은걸 느낄수 있는 명품영화다'],
#  [8,
#   '아무 생각없이 보러 갔다가 스트레스 잘 풀었다. 한번 쯤 있을 법한 소재로 나는 다른 사람들에게 과연 떳떳할 수 있을까 하는 생각이 들게 하는 영화..'],
#  [10, '처음으로 극장에서 육성으로 웃었다 \n재밌었다 몰입도 잘됐고 영화색감이 예뻤다'],
#  [10, '많이 깨닫게 해주는 영화'],
#  [8, '제작비도  얼마들지  않은거  같은데    영화요금을  좀  내리면  안돼겠니      영화는  재미있게  봤다       '],
#  [7, '생각없이 보기엔 좋은 영화. 웃겼긴한데 끝나고나면 딱히 남는건 없는 영화였음.'],
#  [9,
#   '웃기고 놀라고 여러의미에서 시간가는 줄 모르게된 영화. 거기다가 많은 생각을 하게 되네요. 비밀을 아는 것이 좋은걸까? 모르고 그저 잔잔하게 사는것이 좋은걸까? 매트릭스의 빨간약 파란약같은...'],
#  [10, '스릴넘쳤다'],
#  [10, '난 내가 재미 있으면 10점'],
#  [10,
#   '탄탄한 스토리와 억지스럽지 않은 유머로 시간 가는 줄 모르고 봤던 것 같다.이서진, 조진웅의 연기가 다소 어색하긴 했지만 오랜만에 킥킥거리며 편히볼 수 있는 영화. '],
#  [6, '난 완벽안 타인보다 최고의 이혼에 한표!'],
#  [9,
#   '주인공들과 비슷한 나이때라 백퍼 공감합니다..\n물론 원작이 이탈리아영화라 좀 과한 면도 있지만..나이가 들수록 그냥 너무 진실을 알려하지말고 사는게 낫다는 감독의 메세지에 넘 공감~~\n왜~?!!인간은 완벽하지 않으니까..남녀관계든 모든 인간관계에도 ...'],
#  [10, '공감100'],
#  [9, '치밀하게 잘 만든 영화~'],
#  [8, '재미있는  인간세상 이야기 한편 .  볼만함.  '],
#  [9, '한편의 연극을 보는 느낌!  부부가 보면 서로 의심할것 같은 영화 뭔가 여운이 남는 영화이다'],
#  [7, '넘   공감이  많이가는  현실부부  이야기\n늘  살면서  동상이몽    ....\n사는게   참      ~~~'],
#  [7,
#   '완벽한 타인... 슬프기도하고 익숙하기도하고 무언가 가슴을 짓누르는 것 같은 통증을 느끼게도 해주는 말이다. 점점 더 완벽해져야만 살아남을 수 있는 이 사회에서 가식적으로라도 완벽해지려고 하는 우리들... 과연 누구를 위한 완벽함일까... 타인에게 완벽해지기 위해 스스로에게 점점 더 거짓말을 하게 되고 그로 인해 맺어진 인연들... 결국 그 거짓된 완벽함으로 인해 시간이 흐를수록 우린 이 사회에서 점점 더 혼자가 되고 타인이 되어가고 있는 건 아닐까...'],
#  [3, '완벽하게 남자 시선에 맞춘 쓰레기 영화'],
#  [9, '재미와감동 솔직한 우리네 얘기일수도 잇다는..'],
#  [10, '재밌기도하고 딸 장면에선 감동도 있었어요'],
#  [1, '아이들과볼 영화는아니군요\n우리나라영화는 왜 나쁜말을 많이하는지'],
#  [10, '공감100\n넘잼남'],
#  [1, '영화니? 유치찬란이지. 갖다버리세요'],
#  [7, '그냥 우리모습들 아닌가 싶을만큼 시나리오도 좋았고 연기도자연스러웠다'],
#  [9, '아 뭔가 생각하게 되는 영화예요'],
#  [1, '내가 이상한건가\n재밌다는 거에 공감 못하겠고\n성적 주제 빼면 한국영화는 없는건가\n보고 기분이 나빠지는 영화'],
#  [10, '사람사는이야기\n부모,자식,부부,친구,또다른 사랑의 이야기를들을\n가장 현실감있게 이야기로풀어놓은영화\n공감형성100'],
#  [9,
#   '일단 한국 영화라는 점이 놀랍다. \n정말 잘 만들어진 영화 같다 물론 아쉬운 점도 분명 있었지만 충분히 재미도 선사해주고 영화에서 주는 여러 메시지들이 모두 꽤 깊게 생각을 하게 만드는 거 같다. 특히 각본을 칭찬하고 싶다. 물론 조금 과한 면이 좀 있지만  영화를 보고 나와서 돈이 충분히 아깝지 않고 만족스러운 한국 영화 중 다섯 손가락 안에 들어가는 거 같다. \n마지막은 둘 중 하나만이 현실이고 하나는 허구, 꿈 이런 게 아닌 둘 다 현실 즉 다른 현실을 보여주는 거 같다. 꼭 현실은 한 가지라는 법이 있는가 영화에선 두 가지 모두 현실이라 생각한다.'],
#  [9, '꿀잼 연기도 좋고 시나리오도 좋고 생각도 깊어지는 영화'],
#  [2,
#   '뒷끝도 기분도 안좋은 영화..\n대사땜에 웃은 부분도 있었지만 보고 났을때 \n찜찜하고 돈이 아깝다 생각됨\n이걸 왜 재밌다고 하는지...'],
#  [10, '매우 볼만하다'],
#  [7, '돈 아깝다. 집만 나와. 그래도 볼만은 했다'],
#  [10, '잼있게 봤어요.\n염정아씨 연기 최고 입니다'],
#  [10, '박장대소!!  시간가는  줄  모르고 봣네여'],
#  [9, '시나리오가 예술이다. '],
#  [10,
#   '정말 재밌는 연극 한편 본 것 같습니다. 인물 한 사람 한사람 모두 살아 있네요~~ 정말 재밌게 봤습니다. 조만간 헐리웃에서 시나리오 판권 사가겠네요~~~ 시나리오가 너무 좋고 배우들 연기가 너무 좋은 작품입니다. '],
#  [10, '최고의 영화였음\n웃겨죽는줄\n특히게이부분\n많은걸 생각하게하는영화\n다들 우리이야기'],
#  [9, '나는 재밌었음\n조진웅님 연기 배역이 잘 어울렸고^^'],
#  [9, '잘 만든 영화..대사하나하나가 예사로 안들리더라는...40대이상이라면 무조건 보시라...'],
#  [1, '돈도 시간도 아까움. 이서진 연기에 손발이 오그라들며  전체적으로 너무 재미없음.'],
#  [8, '새로운  시도의  한국영화\n각본과 배우들의  연기로 꽉 채워진 느낌\n더구나  배경이  내고향  속초네'],
#  [10, '많이 고민하게 만들 소재네요.. 신선합니다..'],
#  [1, ' 주말연속극 수준의 3류 막장드라마'],
#  [2, '이서진씨 참 좋아하는데 같이 나온 배우들하고 칭구하기엔 넘 젊다는 ~  그리고 많이 어색어색'],
#  [2,
#   '배우진 좋고 웃긴부분도 있었지만, 전체적인 내용은 완전별로에요...\n보고나와서 재밌었다~가 아니라 기분나쁘다... 라는생각을 하게 되는영화.\n타인인정 여부를 떠나 인간관계의 신뢰를 모두 무너뜨리는...  '],
#  [7, '혁신적 시도 세련된 블랙코미디'],
#  [10, '영화보면서 많이 웃었고 생각도 좀 하게 됨 \n조진웅씨 연기 최고입니다 '],
#  [10,
#   '나 40대인데 이게 왜 15세 이상 관람가인지 모르겠다..결혼 생활 10년 쯤 해본 사람들이 보면 많은 생각과 이해가 되기도? 하는 기혼자로써 40대라면 볼만한 영화 ^^'],
#  [9, '최근들어, 영화보면서 유쾌하고 생각하게 되는 좋은 영화를 만난거 같다.'],
#  [6,
#   '장소가 식탁이 중심으로 흘러가니 영화보다 연극으로 만들면 더 재미 있을 듯... \n그리고 이서진 출연은 봐도봐도 어색함. 욕하는 것도 이상하고 유해진, 조진웅씨하고도 친구로 반말하는 것도 어색함.'],
#  [9,
#   '결혼생활 20여년만에 깨달은 사실은 남편은 절대 나와 비슷해질수 없다는 거다.. 이 영화 젊은이들이 보기엔 재미없고 지루할듯 하고 결혼생활 10년 이상인 부부들이 보면 나름 재미있고 의미도 있을것같아 추천하고 싶다. 조진웅과 김지수가 세면대앞에서 나누는 대화 몇마디에 남편도 나도 눈물이 났다.. 전반적으로 웃기고 성드립이 있어서 좀 그렇긴 해도 결혼과 부부에 관해 한번쯤 생각해볼 수 있는 영화다.. 이서진을 무지 좋아하나 이 영화에서는 좀 안맞는 옷을 입은 느낌.. 예전에 "별을 쏘다"에서 악역?으로 나왔을 때 안어울린다고 생각했었는데 딱 그 정도 느낌이었다..'],
#  [1, '딱봐도 재미없어 보이는데 영화볼게 너무없다.....'],
#  [9,
#   '최근들어 젤 재밌게 본영화 \n제작비 엄청 투자해서 재미없는것보다 \n이게 더 재밌었다. \n성드립도 많고 완벽한 내편이 아닌 타인임을 인정해야하는영화라서 그런지 호불호 확실히 갈리는 편인것 같긴한데\n나랑 같이 본 영화관은 진짜 시작부터 내내 박장대소였다\n같이보는사람도 중요한 영화\n\n성드립 많으니.. 애매한이성관계는 안보는게 좋을수도 ㅋ'],
#  [9,
#   '8점이맞는 영화... 10점주는건  알바같고\n\n9점줍니다 최근 가장 많이 웃고 온영화...\n\n영화 보고 나면 뭐 그냥 재미난 술자리에 낀기분\n\n근데 이영화 별점 3개는 이해하는데\n\n1점 2점은 너무했다'],
#  [8,
#   "보.랩 보려했는데 자리가 없어서.\n차선으로 본 '완벽한 타인'\n지루할줄 알았는데.\n다른 영화보다 오히려 빨리 끝나서 놀람.\n열댓번 웃고 나니 끝난 느낌?\n부부.친구에 관해..\n다양한 관점에서 자연스레 풀어나가는 \n스토리가좋았다.\n반지의 빙그르르~~\n원점에서의 시작과 같은 마무리..\n아무리 가까워도 타인이고.\n서로 다 아는듯 해도 결국은 먼 타인..\n다 벗은듯 허물을 보여주는듯 해도.\n우리 내면에는 스스로 지켜야할 자존심.비밀하나씩은\n가져가며 살고 있진 않을까.\n거울에 비친 내모습이 보이는 내 전부도.\n남에게 투영되는 내모습이 전부도 아닌..\n인간 관계는 적당한 거리.관심.이해.배려.\n때론 무관심 이 필요하진 않을지. .\n알아도 모르는척..\n전혀 모르는듯.\n그것이 어쩌면 "],
#  [8, '귀걸이+싸다구=헐..'],
#  [7, '연극 같은 연출이 재미 있었다, 학생들은 잠온다고 지루했다더라, 나이별로 평이 갈릴듯 하다.'],
#  [6,
#   '추잡한 인간들의 추악한 이야기.. \n\n영화니까 영화로서 평가를 하면... \n영상미(딱히 보여준 것이 없어서.. 월식 CG라도 제대로 하지.) 3.0, 음향(현장 마이크가 좀 안좋은 것이었나? 소리가 좀 웅웅대는 느낌이...)  2.0, 시나리오(이야기 하나는 참 잘 엮었다는 생각이..) 9.0, 연기(대부분 연기는 훌륭했다고 봄.) 9.0, 공감(청소년들이 보면 어른들 세상은 다 저러나?하고 염려할 것 같은 내용...  하지만 아무리 친한 친구라고 하더라도 숨길것은 숨겨야 한다는 것과 어디에서 누구에게건 절대 나쁜 말을 하면 안된다는 사실을 새감 깨우쳐 준) 5.0 \n \n결론은 6.0점'],
#  [9,
#   '역시 판도라의 상자는 닫혀 있어야 하나~~~턱이 쩍 벌어져   "대박~~~!!!!!"을 수 없이 외쳐대다 "세상에~~~""헐"역시 모르는게 약인건가......보다......'],
#  [9, '모순덩어리 인간의 내면과 현실 속에서 각자의 환상을 감추며  살아가는 우리의 모습이다.'],
#  [9, '월식은 달 자체가 없어지는게 아니라 가려지는것 뿐임.\n다들 그렇게 살고있는듯.\n사는 건 가끔은 가려있어야 신비로운듯.'],
#  [10, '비밀은 비밀인 채로 여야만 비로서 아름다운것이다.'],
#  [1,
#   '가부장적 남편 모습. \n바람피는 한국 남자들\n\n그러나 영화는 관객에게 좋게 좋게 넘어가면 좋은 일 생길테니  굳이 까칠게 굴지 말란식으로 영화 끝난다. \n\n보는 내내 영화 내용의 70프로 이상이 여성에겐 화가 날 수 밖에 없는 내용들  인데 여성들이 이 영화에 왜 화가나는지 이해 못하겠단 건지 안하겠단 건지 ㅡ 그저 좋기만 하다는 남자들'],
#  [10, '저는 재밌게 보고왔어요\n관객들도 보는내내 빵터지구 \n다같이 즐겁게 본거 같아요'],
#  [10,
#   '정말   영화보면서  이렇게  소리내어  크게  웃은적 처음입니다. 스트레스가 다 풀렸어요.\n시나리오 배우들 특히 유해진배우님 최고예요\n오래오래 기억될거같아요  \n다시보는것도 또다른 재미가 있을것같아요 ㅎ'],
#  [9, '안겪어본 사람들은 모른다 저 심정..'],
#  [10, '너무나 현실적이고 공감가는 영화였다는..'],
#  [4, '낚임~\n출연진 보고 믿고 봤는데 ㅠㅠ\n예고편 딱 그거다\n영화 본 모든사람들\n기분도 안좋고 서로서로 못믿고 ~~~'],
#  [9, '잼있었어요 공공의 나 개인의 나 비밀의 나'],
#  [10, '코미디 보려면 100% 강력추천합니다.'],
#  [9, '잘 만들었다. 예산 많이 안 들이고. 한정된 공간에서 배우들 연기와 대사만으로 끌어 가는데도 시간 가는 줄 모르고 봤다. '],
#  [8, '사람들은 상대의비밀을 단순한 호기심으로 알고 싶어한다.\n비밀이 밝혀졌을때 서로가 감당하지 못할것을 알면서도.'],
#  [0, '영화 초반 애들 욕설시작부터 끝까지 불쾌하기 짝이 없던 영화.'],
#  [7,
#   '재미있게 잘만든거 같아요\n조진웅이  딸에게 아빠로서 한 말이\n참기억에 남고 나중에 나의 아이들이 커서\n그리한다면 나도같은말을 해얄꺼같네요\n\n알아야될것.알지말아야될것.알아도 모른척할것\n그거만 알고 살면될꺼같아요'],
#  [3,
#   '하  , , , 감독이 너무햇다,,\n집안구석에서 서로서로 비밀과 부도덕함으로 가득찬 대화들 , , , \n서로 속이는것들이 부부사이에 그리 많았던가 , ,\n전화기에 그리 부도덕이 횡행하는가,?\n실지 보는 내내 짜증이 나서 혼났다 ,\n영화는 집들이 가서 하루종일 싸우고,ㅡㅡㅡㅡㅡ기분 잡치는 영화'],
#  [8, '2시간 동안 아무일 없을 내 폰이 쓸모 없게 느껴졌다'],
#  [1,
#   '정말 돈 아까웠다. 보헤미안 랩소디 시간이 너무 늦어서 걍 적당한 시간대 있는 완벽한타인봤는데... 아이고 중간중간 나가고 싶어서 꾹 참고 있다가 사람들 몇몇 나가길래.. 그리고 나랑 같이 봤던 친구가 나가길래 나도 나왔다... 돈이 얼마나 아까웠는지... 진심 제작비도 연기자들 출연료 말고는 얼마 들지도 않았겠더라... 이런 영화를 내가 돈주고 봤다니.. 너무 아까웠다...'],
#  [7,
#   '잘 짜여진 각본,  배우들의 탄탄한 연기력, 좋은 소재가 잘 어우러진 작품이다. 염정아 유해진이 영화를 살린 것같다. 이서진 조진웅 역시 양념이고 다만 윤경호역의 게이와 이서진의 상대역으로 나오는 나이가 어린 여주 그리고 유해진에게 야한사진을 보낸다는 설정은 좀 억지설정인 느낌이다. 오랜만의 좋은 영화다.'],
#  [10,
#   '큰기대없이  가볍게 보고싶어 본영화 혼자보러갔지만  소리내서  웃었어요   평일 오전시간이라 10명남짓  객석이 채워졌지만  다들 소리내여  웃었습니다. '],
#  [2, '수준이하의  내용 .돈이 아깝다 .'],
#  [5,
#   '같은 얼굴... 완벽한 타인... 근데 조금 더 세고 강하게 만들 수 있는데 이정도로 약하게 뽑아내기에는 소재와 대본이 좀 아깝다.'],
#  [2,
#   '이탈리아 블랙 코미디. 억지싱황에 웃음이 안나온다. \n알렉스 발기를 시키고 게이가 나오고 전혀 일상적이지 읺은 억지 싱황들. \n마지막에 힌반 웃었다. 거기서 인셉션이 왜 나와. \n이 배우들로도 조합을 못 만드는구나. 한심스런 영화'],
#  [5, '진짜 좋은 배우들의 막장드라마...'],
#  [9, '별로 기대하지 않고 보러 갔는데~~연기도 좋았고 스토리도 좋았어요.  영화가 의외로 볼만했다는~~~'],
#  [9,
#   '나이별로 호불호가 갈릴듯 이해되고 공감가는 부분이 많았지만 극중 인물들의 직업이 너무 전문직이어서 살짝 괴리감 들었음. 선생이 가장 안풀린 직업이라니'],
#  [2, '?? 뭐지 이 영화는.....'],
#  [9, '너무 재미있게봄 어제봤는데 아직도 웃김 생각하면웃김\n근데 그냥마냥 웃긴영화는아님\n나올때 생각많아지는영화'],
#  [1, '진심 웃을 준비 하고 들어갔는데\n딱 두번 웃었다 다른 사람들도 그때 빼고는 안웃더라 영화 자체가 장르가 애매하다'],
#  [9,
#   '현실성있어서 오히려 거부감을 느끼게 할수있는 영화\n아주 잘만들었단 생각\n배우들 각자의 캐릭터 잘 만들었구\n4명의 소꼽친구 중심으로 4커플 이야기?\n각자의 숨겨놓은 비밀을 가지고 있기에 결혼생활이 유지된다는??\n어떤 삶을 선택하느냐는 각자의 선택~ \n코믹요소도 있고 대화도 재치있고 연기도 좋구 중간 센스나 일몰과 연관시키는 설정도 좋았음.\n말했듯이 너무 현실성 있고 공감할수 있어서 더 불쾌하고 기분나쁘게 느껴질수는 있는 영화일듯.\n결국은 상처받는건 누구일까.. \n만일 저 4명의 남자중 선택해야한다면 누굴 선택할까. 하는거? '],
#  [9, '재미있게 봤네요...'],
#  [2, '걍말로웃김\n재미없음\n뭐하자는건지'],
#  [8, '...'],
#  [10,
#   '남친이랑 조조로 보고왔는데 재밌네용ㅋㅋ 큰 영화관에 서너명 관객분밖에 없어서 맘편히 봤는데 맘편하게 웃으면서 재밋게 봤습니다^^!'],
#  [1, '진짜 노잼 남는게 없음'],
#  [6,
#   '전 이런 영화 별로 좋아하지 않습니다.\n짠~~한 감동이 있는 그런 영화가 좋은데 이런 영화는\n제 취향과 달라서...\n그러나 아무 생각없이 오랜만에 맘껏 웃고 왔어요.'],
#  [8,
#   '제작비 별로 안 들이고\n재밌게 만든 영화라 생각합니다\n보는 내내 빵빵 터집니다\n다만 영화의 재미를 위해\n성적인 부분을 많이 부각한 점은\n감안하고 봐야할 듯 ....\n아무리 화통한 부부\n다 안다고 생각하는 연인\n아무리 친한 친구 사이에도\n서로가 모르는 부분이\n있을 수 있고\n특히 은밀한 사생활은\n알 수가 없다는 걸 새삼 알았다\n모든 사람에게는\n세 가지 영역이 있다\n첫째 공적인 존재\n둘째 개인적인 존재\n셋째 비밀스런 존재'],
#  [5, '그냥 오락영화 가볍게 보실분들에게 강추'],
#  [9, '즐겁게 웃고\n생각하다 갑니다'],
#  [5,
#   '영화에다가  뭘 기대했길래  돈이 아깝다는건지 모르겠네?\n돈 값은 충분히 하고도 남더만\n한번 웃어보자는데  웃지도 못하는 찌그러진 인생들 아닌감?'],
#  [1,
#   '여기 후기보고 어제 마눌이랑 갔는데.. 뭐 전혀 재미가 없는건 아닌데.. 진짜 돈주고 영화관에서 보기엔 정말 아닌것같습니다.  사적이던 공적이던 관계유지를 위해서 다들 가면같은거 조금씩 쓰고 살잖아요.. 그애기에요.. 그냥... '],
#  [0, '돈아까워요 보지마세요\n작가 감독 지적 수준이 의심스러움'],
#  [0, '역겨움'],
#  [10, '유쾌하고 씁쓸한..간만에 배꼽잡고 본영화!\n모르는게 약이다~~~~^^'],
#  [1, '말장난   피곤하다 '],
#  [4,
#   '제목에 맞추려 현실보다 더 작위적인 스토리로 무리가 있으나 그냥 아무생각 없이 보고 웃고 오면 좋은 영화ㅡ 단 집에서 무료로 보는 조건으로'],
#  [9, '재밌고 불편한 영화'],
#  [9, '유해진 진짜 왜케 웃기냐 ㅋㅋㅋ'],
#  [8, '한편의 연극을 본 기분. 아이디어가 참신했다. '],
#  [8, '배우들 연기도 좋았고 스토리도 좋았고\n잼났음~~~'],
#  [1, '어설픈~~'],
#  [10, '이서진빼고 흠없는연기 존잼탱'],
#  [4, '40대를 위한 영화\n청소년 관람가라 하기에는 섹슈얼 코드와 거친 말이 넘 많음 '],
#  [2, '주변에서 재밌다고 해서 너무 기대를 한 탓인가.. 중후반까지만해도 흥미진진했는데 하.. 맥빠짐'],
#  [9, '남자는 안드로이드,여자는 ios 방식으로 사고한다는 데서 빵 터졌네요 ㅎㅎ'],
#  [9, '스릴러보다 더 무사운 영화. 미혼은 알 수 없는 영화'],
#  [7,
#   '규모나 배우빨로 밀어붙이다가 망한 영화들에게 좋은 대안이 될것 같은 영화다.\n이서진 배우와 유해진 배우의 역활을 좀 바꿨다면 어떠했을까라는 생각이다.\n특히, 이서진 배우의 역활이 너무 가벼워 평소의 이미지와 맞지 않서 몰입에 방해를 한다.'],
#  [9, '웃기고 재미있어요 '],
#  [10, '세상에는 완벽한 사람들이 없듯이 완벽한 관계도 없다.'],
#  [2, '근데 이서진은 친일파 잔손 아닌가? \n연기력도 별론데?\n왜 자꾸 친일파들이 미디어에 순한 양 처럼 나오는거지?'],
#  [10, '많이웃을수있는영화입니다^^\n그런게임은위험하네요~!!'],
#  [10, '오랜만에   많이 웃고나왔네요..'],
#  [8, '그냥 웃고 넘기기 힘든 여러가지 깊이 생각할 거리가 많은 영화였다. 배우들의 기존 캐릭터에서 벗어난 연기들도 좋았다.'],
#  [6, '코믹하다고해서 기대했두만 오히려 무거운 느낌. \n영화가 사람을 속였음. 기분나빴음. 김빠지는 느낌'],
#  [10, '재밌더구만'],
#  [9, '30~40대라면 누구나 공감 할 수있는 현실적인 영화!!'],
#  [9,
# ...
#  [10, '정말 재미있게 봤습니다. 화려한 CG,액션 하나 없어도 긴장,반전,웃음,감동이 있어요. 순전히 시나리오의 힘~'],
#  [2, '재미  없어요. 저예산 영화'],
#  [8, '이서진이 연기를 더 잘했다면 10점. 감동까지는 없어도 재미있고 여운이 남는 영화에요. 12,000원이 아깝지 않은 영화.'],
#  [0, '글쎄, 마냥 웃으면서 보기엔 찜찜함이 남는 영화'],
#  [9, '관객수가 많아서 아무생각없이 봤는데 \n연기도 연기지만 정말 재미있게 보고왔네요 '],
#  [10, '참신한 소재의 영화... 계속 빵빵터지고 여친과 넘 재밌게 봤습니다^^'],
#  [9, '영화관에서 너무 웃어서 눈물 흘림 죽는줄\n가족과 볼만한 영화가 아님  스토리 라는건\n대단치 않지만 킬링타임으로는 최고'],
#  [10, '별 기대없이 보몈 재미있는 영화^^'],
#  [8, '연기를 너무 잘하셔서 현실감 있음\n간만에 유쾌하게 웃다 나왔네요 '],
#  [9, '재미 있어요.\n있을수 있는 현실감'],
#  [10, '오랜만에 빵빵 웃음터지는 영화ㅎ\n보면서 계속 생각에 잠기는 영화ㅎ\n속초에서 봤는데 첫장면부터 다들 빵터짐 ㅋㅋ'],
#  [9, '완전 괜찮은 영화'],
#  [8, '성소수자에게 상처와 방어벽을 다 주는 영화.'],
#  [8,
#   '남편이랑 봤는데\n아주 좋았어요\n다양한 시각에서\n생각해볼수 있는 시간\n아~ 그럴수도 있겠구나\n실은 우린 완벽한 타인이었어!!\n음~ 이런 내용을 소재로\n영화를 만들어줘서\n감사해요~^\n비오는날 멋진 시간이었어요~^*'],
#  [10, '연기구멍없이 아주 훌륭함ㅋㅋㅋ'],
#  [9, '조금의 과장도 없으면 영화가 안되겠죠.\n전체적인 흐름도 자연스러웠고 끝나고도 나쁘지않은 여운이 남네요~^^'],
#  [8, '찰진 코미디 하나 잘 봤네.'],
#  [9,
#   '오늘 보고 왔어요..신선했어요 너무 재미나서 마니 웃으며 본영화입니다 최근에 범죄영화가 마니 나오던데 .. 스토리가 잔잔하면서 펙트가 있어서 좋았어요 '],
#  [10, '.'],
#  [10, '매우 재미있는 영화.'],
#  [8, '즐거움. 연기 구멍 없음.\n\n조금이라도 서로에 대해 고민하는\n연인 또는 부부에게  강추.'],
#  [10, '재밌네요\n연극적임 요소도 많고 \n이런식의 영화가 많았음 해요\n치고박고하는 것 말고'],
#  [1, '돈주고 보기 너무 아까운영화 2시간동안 혐오발언만 듣고옴 좋은배우들을 이런영화에 쓰다니 '],
#  [9,
#   '2시간 재미있게 봤어요. 유해진님 팬이라 봤는데 역시 유해진님은 코믹한 연기 할 때 최고인거 같아요ㅎㅎPPL이 너무 많아서 좀 거슬리기도 했지만 명배우들의 명품연기 보는 재미만으로도 충분히 즐거웠습니다. '],
#  [10, '우아한 동상이몽 스릴러\n(프랑수아 유머보다 세련되고\n헐리우드 플롯보다 리얼하다)'],
#  [9, '잼있었습니다. 달빛연기 ㅎㅎ'],
#  [10,
#   '우울한 마음이 송두리채 날아가게 해준 영화 입니다. \n주변에 장사 안 된다고 고민 하거나 하는 분들에 적극 추천 합니다...'],
#  [9, '웃기다\n사실이다\n인간의 모습이 그대로...그래서 잼났다\n\n난 아니지만'],
#  [9,
#   '있을 법한.. 어른으로 살아가다보면 어쩔 수 없는 사회적 모습을 보여야하는 상황들.\n속을 까발려보면 다름에 상처받는 사람들. 그래서 겉치레가 필요함.\n친구들 모임에서 있을 법한 대화들과 상황들이 자연스럽고 치밀하게 짜여져있어요..'],
#  [10, '정말 재밌게 잘봤습니다~그리고 마지막은 지금의 나를 되돌아보게 되는 영화였습니다'],
#  [9,
#   '잼나던데??\nㅋㅋㅋ특히  유해진특유의 코믹연기..\n이서진의 능글맞은 바람둥이연기..\n이제까지보지못했던 이서진캐릭터같음..ㅎㅎ\n보는내내 배우들이  툭툭던지는 유머스런대사들땜에 2시간동안 잼나게본거같다...\n억지스럽지않은 유머가맘에든다...'],
#  [9, '이정도는 만들어야 영화지 간만에 기본은 하는 한국영화'],
#  [9,
#   '이거 보고 불쾌하다 3류다 어쩐다 하는 사람들은 다 등장인물들처럼 캥기는 구석이 있는 사람들인듯 ㅋㅋㅋ 뻔한 소재로 1류 영화를 만드는 훌륭한 연출의 영화 잘 봤습니다.'],
#  [10, '완벽한 영화\n완벽한 연기\n염정아배우님 연기 대단해요.'],
#  [9, '재밌게 봤음 ㅎ '],
#  [9,
#   '가볍게 본 영화였지만 현실을 적나라하게 보여준 영화~ 이서진 쓰레기?역활과 유해진등 배우님들의 짧지만 강한 개성의 연기력이 좋았습니다~간만에 코믹하고 씁슬한  생각을 하면서도 누구에게나 비밀스런 이야기는 확실히 비밀이어야 하는 영화 ~'],
#  [2,
#   '사랑과전쟁 극장판. 역시 한국인에겐 막장이지.  고추장 된장 초장은 좋은데 드라마나 영화는 막장은 싫다정말. 언제까지 끕 떨어지는 소재만 울거 먹을건가? 그것도 외국영화 돈주고 빼긴거라니 ㅎ 막장도 빼겨서 만드는 수준이 한심할따름'],
#  [9, '영화보고 나오면서 커플들 서로 의심하고 찜찜했을듯 ㅋㅋ'],
#  [8, '간만에 혼자 심야 굿.'],
#  [10, '오늘 심야영화로 봤는데 정말 재밌었어요!ㅋㅋ '],
#  [10, '최근 본 영화중에 가장 많이 웃었고 돈이 안아까웠음\n아마 대박날듯 .\n감독이 뇌섹남인지 잘 찍음 '],
#  [3,
#   '그냥 중간중간 웃긴 연출에 웃었지.. 불쾌한 소재와 관념들 .. 보고 하루종일 기분이 별로였습니다. \n전형적인 한국형 B급감성'],
#  [8, '최근본영화중 가장큰여운..찝찝한 기분이 가시질 않네..'],
#  [10, '근래 본 한국 영화중에 제일 웃기고 무섭고 여운이 남았음'],
#  [1,
#   '최근 잘나가는 한국 드라마나 영화로 봤을때 감독의 주제의식 및 표현력이 부족하고 시나리오의 완성도 많이 떨어짐 \n처음 나오는 초등학생씬들은 왜 나왔는지 ...'],
#  [10, '이거 진짜 재미남'],
#  [10, '재밌음\n많이 재밌음'],
#  [9, '절묘하게 맞아떨어지는 타이밍과 엮이는 스토리에 빵빵터짐ㅋㅋ특히 유해진 염정아 배우의 연기가 좋았음'],
#  [1, '영화보는 내내 핸드폰만 봤네요'],
#  [10, '오랜만에 웃고 생각하고 좋았네요. '],
#  [1, '보다가 뛰쳐나왔다. 재미없고 내용도 별루다. 진짜 평점알바가있다는걸 알수있었다. '],
#  [8, '보는 내내 웃음과 씁쓸함이 교차되는\n배우들 연기력 지리고\n내용도 생각할게 많음'],
#  [10, '끝날때 까지 끝난게 아니영화 ..\n신나게 웃게하고 또 많은 생각을 만든영화..'],
#  [10, '사람은 누구나 꼭 감춰야할 비밀들이 존재한다는 것을 알게해준 영화'],
#  [10, '최고'],
#  [9, '오랜만에 맘 것 즐긴 재미있는 영화\n뭔가 그래도 희망이 있다라는 메시지도 좋다'],
#  [6, '제작비 저렴한 영화. \n속초 음식 홍보 영화. \n남자는 다 똑같다고 결론 짓는 영화. '],
#  [8, '남는건 없지만 보는 동안은\n재밌는 영화~'],
#  [7,
#   '40대중년들의 이야기라 재미는 있었지만\n씁쓸한  마음이 들게하는 영화.\n진정한 사랑을 찾아볼수 없는  세속적인 이야기.\n또 은근 동성애를 미화하고 자연스러운 것처럼 \n소재에 넣은것도 정말 이시대의 타락상을 보여줌'],
#  [8, '가볍지만\n결코 가벼울 수 없는 영화~'],
#  [8, '다양한 시각과 소통.'],
#  [5, '잘만든 드라마, 쇼프로 보는듯... 영화로 만들기엔 소재가 너무 약한것 '],
#  [2,
#   '저녁 식사 초대 받은 친구 부부집에서 \n각자의 친구 부부들이 식탁에서 부부 싸움하는 장면 \n거의 식탁에서 부부 싸움하는 장면만 나옴.. '],
#  [9,
#   '잘 만들었고 생각할 지점도 많습니다. 물론 뒷부분이 극으로 치달았더라면 더 좋았을 거라는 아쉬움이 남지만 이 마무리도 나름 괜찮네요. '],
#  [6,
#   '영화의 메시지는 누구나 비밀을 갖고 살아가고 그 점이 파국을 향해 갈 때지만 정말 영화라고만 볼 수 있는 가정이다. 그것보단 영화를보면 착한 사람이 결국 피해자라고 생각이 들 정도. 남들 다하는 일탈을 착한사람만 안하네.'],
#  [8, '배꼽빠지는줄ㅋㅋ'],
#  [10, '다시 한 번 봐도 괜찮을듯\n2탄으로 여자들 얘기도 해줬으면 싶네요'],
#  [9, '재미있네 ㅋ'],
#  [10, '정말 재미있는 영화! 강추 다만 연인 혹은 부부끼리는 쫌...'],
#  [3, '유해진 연기가 돋보이는 영화\n지루해서 뒤로가면서\n잠이오는 영화'],
#  [10, '아 재밌어요. 웃기면서도 여운이 남는 영화. 보고나서 결혼이 뭘까 친구가 뭘까 관계에 대해 생각했어요 ㅎㅎ'],
#  [9, '인간관계에 대해 생각하게 하는 영화'],
#  [9, '어제 심야로 혼자봤는데 은근 몰입됨. 글고 역시 믿고 보는 유해진 ㅋㅋ'],
#  [5, '유해진제외하고 지루지루 너무 설정인거아닌지.. 그래도 뭔가 생각하게하는  씁쓸함이 남는다'],
#  [7, '관계란 비밀 덕분에 유지 되는 것.'],
#  [9,
#   '때로는 모르는게 약? 비밀을 끝까지 모르고 가정의 평화를 지키느냐, 배우자의 비밀을 오픈해서 가정이 파탄나느냐.....누군들 저 작은 사각기계에서 자유로울 수 있을까.....'],
#  [1, 'ㅈㄴㅈ'],
#  [9, '넘잼있었어요.~'],
#  [9, '간만에  웃었네요\n요즘  친구  부부들  애기\n아닌가?'],
#  [10, '최소한의 제작비로 벌써손익분기점 180만을 넘어 400만돌파라니 감독님의 극을 감칠맛나게하는 노련미가 돋보이는 작품이었습니다'],
#  [3, '유해진은 정말 재밌는데, 나머지는 영... 확실히 감독 수준이 떨어지는게 영화에서 확 티납니다.'],
#  [9, '영화비가 아깝지 않은 영화였습니다.\n다시 보고 싶어요.'],
#  [6, '너무 재밌지도 재미없지도 않았던 영화...  때로는 모르는 게 약이라는 말이 정말 와닿는 내용...'],
#  [9, '한마디로 잼나네요\n근데 세번째인생은 비밀지켜야'],
#  [10, '재미있기만한데..\n재미없다고한사람들 저런거하면 걸릴게 있어서 그런가'],
#  [9, '송하윤 이라는 배우가 완벽하게 인식되는 영화....\n이쁘고 연기 잘하고.... 앞으로 기대가 되는 배우'],
#  [10, '재미있었어요!'],
#  [7, 'SoSo'],
#  [9, "현실적이다'"],
#  [9, '3가지의 자신'],
#  [1, '진짜 재미없는데요 어느부분에서 재미를 느껴야하죠 '],
#  [7, '화려한 볼거리는 없으나 가볍게 웃을수 있고 주위 사람들과의 관계에 대해 생각하게하는 영화.'],
#  [9,
#   '내 아내를 더 존중하기로 마음먹게 한 영화...\n믿고보는 조진웅, 김지수...그리고 최애유해진까지... 잘 봤습니다.\n키티할매가 공개됐다면 더 좋았을껏을;;;'],
#  [5, '잠간 힐링의 공백 타임은  굿 이네요'],
#  [9,
#   "영화가 끝난 뒤 제목을 이해했어요. \n왜 '완벽한 타인'이었는지. \n\n어쩌면 우리는 부부이건, 가족, 친구이건 서로가 완벽한 타인 일 지도 모릅니다."],
#  [9, '제법 재미있어요'],
#  [7, '단순한 발상에서 민낯을 보는 스토리는 재밌으나 이서진씨 연기가 저정도였나 싶은게 자꾸 몰입 방해되더이다'],
#  [9,
#   '결국은 다 남이라는거. 내사람이라고 믿음을 가지고 믿고사는거지뭐.  너목보라는 드라마에서 남의 마음을 읽는 초능력을 가진 주인공이 얼마나 힘들어하면서 음악만 들었는지 기억남 ㅎㅎ.  결국 모르는게 약'],
#  [10, '진짜   많이 웃게해준 영화네요'],
#  [9, '갠적으로 마음에드는 결말임.\n교훈"완벽하게 속이지못할거면 시작도하지마라."'],
#  [8,
#   '처음 어린이들의 연기는 꽝~\n나머지 스토리가 탄탄하고 연기도 좋았는데\n단...이서진의 욕 연기는 꽤 어설프고. 맥락에 안맞는것 같았음.'],
#  [7, '재미는 있어요\n억지스런 점도 있고 ~'],
#  [10, '뭔가 생각이 많아지는 영화'],
#  [10, '진심 보다가 웃음보 터졌다 ㅋㅋㅋㅋ\n영화 그 자체로는 정말 웃기고 재미있지만 현실 반영해보면 뭔가 씁쓸한 영화'],
#  [10, '두시간 동안 웃고 나왔지만 보고난후 생각이 많아지는 영화!'],
#  [9, '알려야 되는 사실과 감추어야 되는 사실의 판단'],
#  [9, '이정도 한국영화면 완성도 괜찮음'],
#  [7, '이서진씨 연기 어색했구요. \n보고나니 생각이 많아지네요.'],
#  [8, '함 보세요...이런 영화도....소재가 참 좋아요...현실적인 소재....웃음도 나오고....'],
#  [7, '그 사람의 모든걸 알기에 친하다 생각하지만,\n그 사람의 모든걸 알 수 없어 친할 수 있는 것.'],
#  [10, "'완벽한 타인'넘 재밌어요!! "],
#  [7, '이서진 개중에 발연기 \n아주 깔깔대며 잘봤습니다 유해진씨눈 정말 연기 갑이네요 감탄하며 봣어요 \n영화 재밌네요'],
#  [9, '현실적  문제점을 재밌게 잘 표현했고\n한번씩 웃게해줌에 기분좋은 시간이었다'],
#  [10,
#   '너무너무 재미있었음~충분히 있을수도 있는일이니 실감났음~느낀점은 누구나 비밀이 있다는점을 알게됨~그래서 힘이났음~~~누구니 이중작인 면이 있으니 자책 안해도 됨~^^아 넘넘 즐거웠어용~^^아줌마들 아저씨들 넘 잘봤을서같아용♥사랑합니다 완타♥완전 타타타♥'],
#  [9, '중년의 관점에서 충분히 공감가는 영화.\n난 마지막에  그집 딸이 무사히 집에 들어와서 안심이 되더라 ㅋㅋ'],
#  [1, '진짜 욕하면서 나올뻔함 진짜 진짜 돈아깝다.. 드라마보다 못하다'],
#  [9, '다들 연기가 넘 좋아서\n다만 이서진 역할이 안어울림\n욕도 많이하는게 넘 어색함'],
#  [1,
#   '오바 연기와 오글거림 투머치 설정 저녁 먹는 2시간 남짓 그 많은 비밀과 사연들을 단순 핸드폰 하나로 노출 시키려다 보니.. 김소월 역의 라미란 전화로 주저리주저리..  짜맞추기.. 진짜 오글거림. 모든 설정이 오바오바. 지나치니 촌스러움.. 신혼이라는 설정으로 방방뜨는 송하윤 목소리와 연기 / 어울리지 않는 배역에 무게 잡는 유해진 연기도 거슬리고.. 윤경호 배우의 자연스러운 연기 정도..       '],
#  [10,
#   '한국영화중에서 간만에 재밌었어요!!!\n러닝터임이 지루하지 않게 이어지고 과한 설정도 있었지만 현실성있는 그러한 주제였어서 그럴수도 있겠다 라는 생각이 들었습니다\n추천추천\n단 가족이랑은 보지 말것....'],
#  [3, '솔직히 정말솔직히 평점주자면 별셋'],
#  [4, '잼 없었음 '],
#  [10, '재밌게 봤어요'],
#  [6, '아까비~~~ 2% 부족\n그래도 간만에 즐겁게 봤다.'],
#  [1, '너무 재미없어요…영화라기보다는 유치한 단막극 수준'],
#  [7, '혼자만 보시길 권함...'],
#  [6, '오늘 봤는데 그냥 한번 웃고 가볍게 볼 영화..\n디테일의 세련됨은 없지만 잼있었어요 ㅎ'],
#  [3,
#   '우리나라 아줌마들 참 매너없다 웃긴다고 지네집 안방인양 박수까지 친다 제발 영화관좀 오지마라.아주 짜증난다.그냥 집에서 tv들이나 쳐보세요.핸드폰벨소리에 장면마다 수다에 자기집 안방인줄 안다.수준이 안되면 영화관엘 오지마라.그리고 자식들도 부모한테 영화관 매너 철저히 가르쳐드려라.시장바닥에서 보고왔다.영화는 소재는 참신하나 갈수록 늘어지고 염정하와 유해진이 싸우는 장면은 신파같더라.그리고 그런 부자집에서 꼭 찍어야 됐나?있는 것들은 이영화보다 더 숨기고 산다는걸 감독은 보여주고 싶었나 보다.친구마누라 건드린 이서진이 같은 세상에서 살겠지,,,그런데 동성애는 왜?껴 넣었을까?일침을 가하기 위함인가?'],
#  [9,
#   '다 알려고 하지마라\n알면 알수록 다친다\n사람은 누구나 아무에게도\n말 못할 비밀이 있는법\n난 웃기지 않더라\n그 상황상황들이 \n그냥 짜증나더라'],
#  [9, '식상하지않아재밌다'],
#  [9, '오랜만에 엄청 웃었어요 ~ '],
#  [10, 'ㅋㅋㅋㅋㅋ ㅋㅋ\n재밌어요  감동도 있고'],
#  [9, '8.5점....재밌음....관객들 여기 저기서 낄깔 거리는 웃음 소리가 넘침.... 관객이 몰리는 영화는 다 이유가 있음'],
#  [9,
#   'ㅋㅋㅋㅋ 아니 진짜 평점 낮은 댓글들 보면 전부다 말없이 1점이나 0점이고 알바많네.. 이런거 밖에 없음. 뭐가 불만이고 뭐가 별로였다는 것도 없어 ㅋㅋㅋㅋ \n\n아무 댓글없이 0점 1점 주는 너네가 더 알바같은데?'],
#  [8, '울엄마 웃겨서 눈물흐리고 뒤로 넘어가실,....'],
#  [9,
#   '40~50대 볼만합니다\n대사 재미있고\n웃음70% 울컥한내용30%\n\n연기 잘하고 찌르고 피나고 박살내고\n그런거 없이 아주잼남'],
#  [7,
#   '가족이건   연인이든  친구든 \n모든 걸  다 공유하고 알아야\n사랑하는 건 아니다.\n몰라도  사랑할  수 있다.\n우리는  모두 완벽한 타인이다.'],
#  [10, '이건 재민는데 안시성같은 쓰레기보다야 훨씬 재미지고 좋던데 '],
#  [9,
#   '염정아, 유해진, 김지수, 조진웅씨 열연에 영화 잘 봤어요~  재밌게 한참 웃고 생각하고.. 여운이 남는 영화네요~\n영화 끝나고 미처 생각지 못한 퍼즐을 맞추고 있었다는............ ㅋㅋㅋ\n\n다들 실제 같은 모습에 역시~ 엄지 척 !!'],
#  [7, '그럭저럭 볼만했네요.'],
#  [1, '알바많네'],
#  [4,
#   '완벽한 억지, 완벽한 왜곡 .. 잘 사는 사람들도 서로를 의심케게 하는 ~ 안 그런 사람이 더 많아요 !!\n밑에 재밋네 좋은 작품이네 하는 분들을 색안경 끼고 보게되는 것은 제 잘못인가요 ㅋㅋ'],
#  [9, '시나리오, 연출력, 연기력의 조화, 마무리까지 깔끔!!!(3갭니다, 3개-보신분은 아시겠죠^^)'],
#  [9,
#   '김지수씨의 발음이 참 특이하네요. 혀가 짧은 거 같은데도 명확하게 들리고, 영배와 태수의 대화는 정말 최고로 재밌고 웃겼어요. 영배역 배우에게 급관심이 가네요. 유해진씨는 역시 명불허전의 연기력. 염정아씨의 교통사고 얘기는 좀 필요없는 얘기같아서 뺐으면 좋을 뻔 했어요. 잘 버무려진 사라다같은 영화였어요.'],
#  [9, '좋은 영화입니다\n추천! 드립니다 '],
#  [8, '웰메이드란 이런 것!! 웃고,울고,생각하게 하는 영화!! \n '],
#  [10,
#   '돈 퍼붓는 영화들 보다가 우와! 진짜 아이디어, 각본, 연출, 연기력으로 완성된 작품을 보니 완전 감동이다. 진짜 너무너무 재밌게, 멋지게 본 영화였다. 박수를 치고 싶다.'],
#  [10, '생각이 많아지는 영화'],
#  [9, '이런 배우들이 있어 감사했고.....유해진 때문에 한 번 더 보고싶은..영화'],
#  [10, '영화 끝나고도 생각하게 만드는 영화!!!\n시나리오,배우 둘다 짱!!!'],
#  [10,
#   '별 생각 없이 제목만 듣고\n영화 예매했는데 너무 잘 봤다 싶더라고요,\n근래에 보기 드문 영화 스타일,,,\n잔잔한 \n어쩌면 우리 생활속에 당연하게 들어온 핸드폰으로 \n생길법한 이야기들 ...\n독이 되거나 약이 되거나....^^ 여러 관점에서\n흥미롭게 잘 풀어내었습니다.\n배우들의 강약 뒷심까지 어느하나 소홀한 역 없고 잘 조절되어\n인상 깊었고요^^ \n기분좋았습니다. 결론도....\n\n간혹 여기다 악플을 남기시는 분 있는데...\n본인이 영화 선택을 하셔두고는 왜 그럴까요\n그런 분은 장르, 별 평점 보시고 다른 영화 보는게 좋을듯요,\n하나의 영화가 그냥 제작이 되나요, 시간과 공이 얼마나 들어갈까요\n오늘 멋진 하루와 맛있는 밥이 주어졌듯이 맛있는 영화 한편 소중하게 봄이 감사합니다.\n자'],
#  [7,
#   '나름 각본도 납득가능한 정도로 잘 짜여있고 배우들 연기력도 괜찮았다. 기대를 전혀 안하고 봐서인지 꽤 좋았다고 생각함. 다짜고짜 인간의 추악한면을 보여주고 결말 흐지부지  끝내버리는.. 그래서 어쩌라고식의 상류사회같은 영화일거라고 생각했는데 보고 나오면서 이런저런 생각도 하게 해주는 결말이었음. 찝찝하게 끝내지 않아서 감독한테 고맙다고 해야하려나ㅋㅋㅋ 아마 마지막장면 아니었으면 졸작이라고 1점 줬을듯 함.'],
#  [7, '정도를 걸어야하는 우리 인생\n길이 아니면 가지를 말아야할것을..\n남자들아 인간답게살쟈'],
#  [9, '기대 이상으로 재미있네요.\n씁쓸하기도 하지만 가족이, 휴대폰이 뭘까 하는 생각도 하게된다.'],
#  [8, '나에게  완벽한 타인도~물론 나도 누군가에게는 완벽한 사람처럼 행동하지만~ 실상은~'],
#  [9, '누구나 숨기고싶은 비밀은 있다.\n다 알려하지마라~\n사는동안 옆에짝에 잘해라 ~이런 느낌 '],
#  [6, '스토리는 괜찮았으나 한정된 공간에서 잡담 나누는 이야기를 꼭 영화관에서 볼 필요가 있나 싶어요 간간히 웃음 터지긴 했지만..'],
#  [9, '인셉션   로맨틱 코미디 버전'],
#  [9, '잼나요 '],
#  [9,
#   '멈추지 않고 도는 반지. 월식동안 인셉션? 두 가지 버전. 아는 게 좋은 걸까? 모르는 게 좋은 걸까? 둘 다 완벽한 타인이긴 마찬가지.'],
#  [9, '각본 연기 굳'],
#  [4,
#   '저예산영화로서 선방. 그러나 너무 주입식 사고의 흐름과  저예산 영화의 한계점인 좁은 공간에서 끝까지 갈수밖에 없던  장면은 보는 내내 답답. 영화보는 후반부는 보는 동안 제법 스트레스 받음.  현대사에 여자들 삶은 과거사. 남존여비를 주제로한 영화?'],
#  [0, '.'],
#  [8, '그냥 웃기기만한 영화는 아닙니다 '],
#  [10, '부부가 함께 잘 봤습니다'],
#  [1, '..'],
#  [9, '처음에는 재미있게 보다가 나중에는 마음이 무거워지네요\n연기력 짱'],
#  [0, '최악....'],
#  [7, '배우들의 연기력과 스토리가 \n너무 좋았어요\n기대이상인 영화'],
#  [8, '유해진과 윤경호 대화 장면에서 빵터졌어요 ㅋㅋ 기대한 것 보다 재밌었어요.'],
#  [3, '영화보고 난 뒤 속이 안좋은적은 처음입니다. 재미 있는것 같으면서 갈수록 이상하게 빠지는 느낌'],
#  [9, '시나리오와 연기의 승리'],
#  [0, '돈 아까웠음'],
#  [0,
#   '마지막에 좋은 방법으로 결말을 맺겠지 기대했는데... \n아쉬웠습니다.  소재가 올바르지못하기에... \n보고 난 후로 속이 안좋았네요...'],
#  [10, '볼만하다 유해진의 코믹연기는 일품'],
#  [6, '그냥...'],
#  [10, '잼나요'],
#  [10, '저렴하게 찍어서 큰 웃음을 준 영화..\n기혼자 강추!!\n이서진 좋아했는데..맡은 역은 별루ㅠ'],
#  [0, '왜 봤나 모르겠네요'],
#  [5,
#   '안봐도 될것같았지만 봤는데 안봐도 되는게 맞다고 느낌\n특유의 90년대 감수성\n자연스러움 세련을 대놓고 추구하니 그 태도가 느껴지면서 오글거렸다\n모든게 너무 과도하고\n한마디로..촌스럽다\n말과 행동으로 모든걸 다 보여주려는건 이렇게 촌스럽고 \n상상력 없음을 나타낼 뿐이야\n90년대에 나왔으면 재밌는 영화라고 평해졌을듯\n중반부 배우 코믹연기로 퉁치려는 의도가 너무 게으르고\n한마디로 짜증났다\n그냥 보지 말걸\n이서진이 똑똑하면 이런 영화엔 안나올듯 하다\n친목도모는 했겠지만 도움될게 없을듯\n조진웅 유해진은 다작배우로 그렇다 치지만\n엄청난 오글거림이 가장 힘들었다\n게다가 구태의연...\n아 촌쓰러\n이렇게 상상력이 0인 영화도 정말 오랜만인 듯 하다\n이런 영화가 최대 신선하단 말을 바보같은 이들한테 들을 순 있어도\n좋은 평가'],
#  [10,
#   '2시간의 시간 공간을 넘어 이야속으로 빠져든다.\n오늘날 우리가 살고 있는 현실의 공간의 소재가 \n작은 셋트장에서 모든것을 소화할수 있었다. \n\n고부간의 갈등\n성소수자의 고민\n친구간의 우정과 말못한 이야기\n부부의 위기와 갈등\n\n오늘날 우리의 현주소가 사실 그대로 표현되었다.'],
#  [10, '그냥 좋다\n따뜻한 카푸치노 한 잔 마시면서 혼자 보고 나오는 화요일 오후가 신선하게 느껴졌다'],
#  [6, '내용..줄거리 별로..극을 너무 억지스레 끌고가는..편집이 영화를 망친..배우들연기력을 감독이 망쳐놓은듯'],
#  [0, '보헤미안 보러가라 민주야'],
#  [9,
#   '책한권을 읽고난 배부른 느낌의 영화였습니다.\n아쉬운건 우리 이서진님의 어색한 신발 ㅎㅎ 역이 조금 아쉽긴 하였습니다.\n그래도 오래간만에 친정엄마와 본 한편의 책한권이였습니다.'],
#  [1,
#   '관람객으로서 씌레기다 \n진짜 보기전으로 돌아가 보헤 봤어야는데 아쉬움과 끝난 뒤에도 한시간정도 짜증나는 기분을 느끼게하는 영화\n재밌었다는 사람도 있음'],
#  [9, '유쾌하게 웃다 반전에 놀라다가 아주 시간 후딱가버리게 만드는 영화. 오랜만에  느낀  맛난 영화.'],
#  [9, '반지가 돌아가면서 다시 원점으로 돌아가는..감독의 굿아이디어\n시간가는 줄 모르고 재미있게 봤네요. 작가도 굿'],
#  [4, '왜 다들 집밖에 나오니 화기애애  해졌지?'],
#  [1, '예고편 조차 재미없는 영화는 오랜만이다 식상하고 뚝뚝 끊기는 신들 '],
#  [2,
#   '납득 안가는 평점, 예매율, 관객수...\n약간의 웃음외에는 그다지... \n최근 몇년간 본 한국영화중에서도 그닥..\n나만 그런건가?'],
#  [7, '배우들이 살린영화.\n소재 자체는 상당히 신선하지만\n극을 이끌어가는 전체 스토리는 다소 과한감이 있어 몰입을 깨뜨린다.'],
#  [8,
#   '영화는 역시 스토리와 구성 ! 제작비와 재미가 비례하지는 않는다는 것 확인.\n많이 웃고, 또 생각도 하게 많드는 영화. \n외국 원작은 보지 못했으나 -역린-의 아픈기억을 감독은 잠시 잊어도 될듯요.^^'],
#  [8, '가볍지만 가볍지만은 않은? \n시간이 금방지나갔다\n갑자기 반지돌아갈땐 인셉션이 생각났다'],
#  [10, '진짜 완벽하게 잼나고 웃겼어요 완존 배꼽잡았네요~~~~최곱니다.'],
#  [9,
#   '우리가 타인에게 감추고 숨기고 속이고 있는 것들, 숨기고 싶은것들을 적나라하게 까발림. 보정속옷으로 감추고 있던 뱃살과 뽕브라, 그리고 평소에 자기가 대물이라고 허세부리다가 다같이 대중탕가서 뽀록나는 느낌? 몰라서 속고 알면서 속아주고 그러면서 사는게 세상이 아닐까. 필요한만큼 보여주고 필요한만큼만 보는게 세상사는 진리.  0점, 1점 준사람들의 공통점. 평점매긴게 이 영화가 전부.'],
#  [8, '비밀은 인류 최고의 발명품'],
#  [7, '원작이 한국작가였으면 10점일뻔,,, 원작자가 뒷심이 부족했었을까? 모든게 현실이 아닌 것으로 빠져나간 듯,'],
#  [0, '보랩 봐라~~~!'],
#  [10,
#   '즐겁게 봤습니다\n여운도 있고 생각하게 했습니다\n젊은날 그리 고민하지 말고 살았더라면 했습니다\n다르다는 것을 생각하지 않았던 것 같아서.....\n웃게해준 분들 감사합니다\n연기쟁이들 모두 멋져요'],
#  [10,
#   '별다른 스펙터클한 장면이 없어도 휴대폰이란 소제 단 하나로 영화를 짜임세 있게  잘 만든거 같아요\n코믹과 진심과 거짓과 짠함과 감동이 함께~ 그래도 내옆엔 내꺼인 당신이 있어 행복 합니다~\n이 영화 저에겐  대박이네요~37살에 거의 흡사한 내용이~~ㅋㅋㅋ'],
#  [10,
#   '훌륭한 각본과 연출, 그리고 배우들의 연기로 적당한 긴장감을 유지한 채 많은 웃음을 준다. 단순히 웃기는 데 그치지 않고 인간 관계나 내 자신에 대해 생각하게 한다. 후반부에 다소 과장된 부분은 아쉽지만 꽤 수작이라 할 수 있다.'],
#  [10, '유해진 ㅋㅋㅋ솔직히 유해진이 진짜 웃김 ㅋㅋ 영화는 스토리랑 연출 연기력이 출중함 근데 유해진이 최고였음 ㅋ'],
#  [8, '재미있음^^'],
#  [6,
#   "서로에 대해서 알고 있다고 생각하지만 각자 무슨 생각을 하는지, 어떤 가치관을 가지고 있는지 모르고 지낸다. 물론 현대 사회에서 핸드폰 차지하는 영역은 단지 연락수단 그 이상의 무엇일 것이다. '우리 친구지?'와 같은 친밀감을 강조하는 말은 오히려 서로 간의 거리감을 강조하기도 한다. 아무리 오래 알고 지내도, 함께 지내도 사라지지 않는 거리감. 늘 드는의만이 하나 있다. 과연 SNS상의 맺은 친구도 친구라고 할 수 있을까."],
#  [3, '불륜을 해야 정상인건가??  내가 비정상인건가? 생각나게 하는 영화'],
#  [9, '신선하고 많은 생각을 하게 되었네여'],
#  [9, '생각을 하게 만드는 영화 전 재미있게 봤어요'],
#  [1, '....영화를 보기 전으로 돌아갔으면...'],
#  [9, '중년부부들은 아마도 누구나 공감을 하면서 볼수 잇을겁니다 씁쓸하네요...주변 사람들에게 이 게임하면 난리가 날듯 '],
#  [6, 'ㅂᆢ통'],
#  [5, '이것저것 가져다 애는 쓰는데, 결국은 뭘 좀 가진 것들의 난잡한 성생활 이야기.'],
#  [5, '그나마 몇 헛웃음을 웃게만든 장면 아니고서는 그냥 막장영화'],
#  [9, '그냥 단순히 웃으면서 볼 수는 없다.\n현실의 모습을 너무 사실적으로 잘 보여주니까.'],
#  [8, '시간가는줄 모르고 봤네요..'],
#  [10, '강추...ㅎㅎ'],
#  [9, '반전이 많아서 재미었네요.   특히 나이먹은 사람들에게는'],
#  [7, '씁쓸...'],
#  [7, '웃기면서 씁쓸한..'],
#  [9, '재밌어요.실컷웃었네요ㅎ'],
#  [8,
#   '이렇게 잔인하게 유쾌하다니. 그러니까 바르게 살면 아무 문제가 없다. 어쨋거나, 스마트폰이 우리 삶 속에 너무 깊숙히 들어와있음에 대한 경각심을 일깨워 준다. 또 그것으로 인해 벌어질 수 있는 상황이 당사자에게는 너무도 끔직하겠지만, 제3자 입장에서는 그저 희극일 뿐. 배우들의 연기가 좋은 편인데, 이서진은 너무나 선한 사람이 억지 악역 연기를 하는 것 같은 어색함에서 아직은 배우로서의 내공이 부족한 것 같아 보이기도 하다. 마지막에 보여주는 글이 상당히 와닿는다. 공적인 나, 개인적인 나, 비밀의 나.'],
#  [9, '행복하게 웃는영화'],
#  [8, '가끔은 모르는게 좋을수도 있는 비밀들..\n공적인 나. 개인적인 나. 그리고 비밀의 나.. 잘 봤다.'],
#  [10, '한번쯤  살면서 되들아보게된 계기가 된듯'],
#  [10, '현재 우리들의 삶 이야기이며\n나의  생활을돌아볼수있는   감명 깊은 영화 였다'],
#  [9, '재밌게 봤습니다.'],
#  [9, '유해진씨 역할  울 남편 성격과 똑 같음 ㅋㅋㅋ 그래서 공감됨'],
#  [8,
#   '극장까지 가서 보고온 영화면 왠만하면 10점 만점이지만 동성애 옹호코드의 왜구스런  주제가 걸려 2점 깎았음 \n그러나 할배 모시고 음식 잘 만들어 팔던 바른 예능 사나이 이서진의 야한 연기 적응안되 오글거림은 감점요소 아님 ㅋ 모든 배우들의 완벽연기와 호흡!! 유진과 윤경호(?!)배우의 찰딱호흡 완전~♥.♥ 연출과 대본이 정말 좋은 영화 ㅋㅋ 지금껏 한국영화 넘 힘줬다 ㅎ 이 영화가 그래서 힘빼고 웃으라고 실컷 웃겼다 ㅎㅎ'],
#  [9, '오래간만에 킬킬 웃으면서  봤고 뭔가 생각하게 해주는 영화..'],
#  [1, '알바님들.. 요세 평점 9점 10점 쓴거 보면 \n알바인줄 알고 걸러요 선동하지 마세요..\n그래야 한국 영화 발전이 있지요'],
#  [6,
#   "감독? 작가? 제작자? 꼼꼼하게 숨겨진 의도한 메세지~  ? 세상은 동성애자들을 변태로 본다. 그런데 이성애자들, 너희들  행태가 더 변태라는거. '이제는 너네들이 진실을 말할때인것같다' ~라는 대사한줄 로   말하고싶은듯~ㅋ \n폰을 소재로 한 블랙코미딘줄~이영화는 성소수자,꿈꾸지 못하며사는 아내들입장을 대변하는 포인트♡"],
#  [6,
#   '영화의 배경이 럭셔리하우스인점...그곳을 크게 벗어나지 않고 내내 촬영을 한 영화입니다.\n\n영화의 소재는 현실을 반영할수 있는 신선한 소재였고 음향효과의 디테일이 살아있습니다.\n지루하지않고 한편의 장편드라마를 보는듯한 느낌이었지만 보고난후 가슴먹먹히 무언가가 남아있습니다.\n\n하나 아쉬운데 있다면 영화의 배경이 럭셔리하우스인점...그곳을 크게 벗어나지 않고 내내 촬영을 했다는 점......이하생략~~~'],
#  [6,
#   '이서진씨 땜에 봤는데   야한 대사와 행동이 너무 오버스로워서 초반  내가 괜히 민망스러웠는데 극 중반으로 갈수록  몰립할수 있었다.\n역시 유해진씨는 무슨 역에도 잘 소화하는것 겉다.~^^'],
#  [8, '뭔가 쓰레기 같기도 하면서 교훈을 주는 영화..이서진이 주인공, 위너로 나오는 영화! '],
#  [9, '가장 한국적인 소재와 가장 드라마틱한 시나리오! 그리고 완벽한 캐스팅!\n1점의 아쉬움은 감독님의 다음을 기대하기에~~'],
#  [8, '나의 가장 큰 치부는 가까운 사람에게 들키지 않으려는 내 모습이 녹아있었다. 타인의 속속들을 알려고 하면 다친다. '],
#  [7,
#   '지루 했는데...딱한번 낄낄 거리면서 웃었다...한 3분 정도....그런데 그 웃음이 영화값 할인해서 6천원 내고 봤는데 그 값은 충분히 했지 싶다...간만에 낄낄 대면서 웃었지 싶다...근래 뭘봐도 웃음이 그닥 없었는데..\n예능 봐도 박나래 하비에르바르템때 한번 웃고 말았는데..그것보단 더 웃은듯 해서...영화표 값은 충분히 했지 싶다..'],
#  ...]

# %%
len(grade_list)
# Out:
# 1612
